# %%
import pandas as pd
import numpy as np


# Importing the fuzzywuzzy library
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from collections import OrderedDict, defaultdict

from tqdm.notebook import tqdm
from pandarallel import pandarallel
from deltalake.writer import write_deltalake


from datetime import datetime, date
from pprint import pprint

from data_analytics import utils

# %%
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
# =========================================================
data_conciliacao_convenios_datetime = date(2023, 8, 30)

this_data_virada = "2023-08-25"
global data_conciliacao_convenios

data_conciliacao_convenios = data_conciliacao_convenios_datetime.strftime("%Y-%m-%d")
data_agora = datetime.now().strftime("%Y-%m-%d")

print(f"{data_conciliacao_convenios}")

print(
    f"""
Data de apuração do faturamento: {data_conciliacao_convenios} {type(data_conciliacao_convenios)} 
Data da virada: {this_data_virada} {type(this_data_virada)}
Data agora: {data_agora} {type(data_agora)}
"""
)
# Out:
# 2023-08-30
#
# Data de apuração do faturamento: 2023-08-30 <class 'str'>
# Data da virada: 2023-08-25 <class 'str'>
# Data agora: 2023-09-12 <class 'str'>

# %%
def display_options(row=7, col=7, largura=50, altura=None):
    display = pd.options.display
    display.max_columns = col
    display.max_rows = row
    display.max_colwidth = largura
    # display.width = None
    return None

# %% [markdown]
# ### Encontre o produto mais semelhante dos dados do concorrente para um determinado produto de nossa empresa usando correspondência difusa

# %%
def find_most_similar_product(our_product, competitor_products):
    similarities = [
        fuzz.token_sort_ratio(our_product, competitor_product)
        for competitor_product in competitor_products
    ]
    most_similar_index = max(range(len(similarities)), key=lambda i: similarities[i])
    return most_similar_index, similarities[most_similar_index]

# %% [markdown]
# ### TODO: eu só quero corrigir o nome do procedimento do lavite

# %%
df_geral = pd.read_csv(
    "data_analytics/202309121116-lavite-tabelas_convenios_procedimentos.csv", sep="#"
)
df_geral.sample(7)
# Out:
#         unidade   ti_id                 convenio codigo_procedimento  \
# 5481     olinda    3117           SORRISO DO BEM            56020058
# 6828   boavista  591277             GOLDEN CROSS            80120059
# 11431  paulista  593659               Particular            86000072
# 14034      pina  593712               Particular            85400017
# 2564     olinda     200           SORRISO DO BEM            25060074
# 2930     olinda     566           SORRISO DO BEM            28050029
# 8454   boavista  592998  SAUDE RECIFE - RECIPREV            83000089
#
#                                                descricao codigo_tiss  \
# 5481                       INSTILACAO VESICAL OU URETRAL         NaN
# 6828              CONSULTA DE ESPECIALISTA EM ENDODONTIA         NaN
# 11431               Aparelho ortodôntico Fixo Autoligado    86000072
# 14034                       Ajuste Oclusal por acréscimo    85400017
# 2564   REC FUNC POS OPERAT OU POS IMOBILIZACAO DE PAT...         NaN
# 2930          ADRENOCORTICOTROFICO (ACTH) HORMONIO (RIE)         NaN
# 8454                               EXODONTIA DE DECIDUOS         NaN
#
#       codigo_tuss                             tabela_convenio tipo_tabela  \
# 5481          NaN                                      AMB 90      outros
# 6828          NaN                         Tabela Golden Cross  particular
# 11431    86000072                TABELA PARTICULAR ORTODONTIA    convenio
# 14034    85400017  TABELA PARTICULAR ODONTOLOGIA RESTAURADORA    convenio
# 2564          NaN                                      AMB 90      outros
# 2930          NaN                                      AMB 90      outros
# 8454     83000089                         Tabela SAUDE RECIFE  particular
#
#        preco_tabela  tipo_id status_procedimento status_tabela  \
# 5481          40.00        1               ativo         ativa
# 6828          21.57       22               ativo         ativa
# 11431        850.00       94               ativo         ativa
# 14034         56.00       94               ativo         ativa
# 2564          28.00        1               ativo         ativa
# 2930         210.00        1               ativo         ativa
# 8454          16.00       22               ativo         ativa
#
#                        procedimento_generico                  especialidade
# 5481                                     NaN                            NaN
# 6828   CONSULTA ODONTOLOGICA EM ESPECIALISTA                    Diagnostico
# 11431              APARELHO FIXO AUTO-LIGADO  Ortodontia e Ortopedia Facial
# 14034   AJUSTE OCLUSAL POR DESGASTE SELETIVO                    Periodontia
# 2564                                     NaN                            NaN
# 2930                                     NaN                            NaN
# 8454                   EXODONTIA DE DECIDUOS                Odontopediatria

# %%
df_geral[
    ["convenio", "tabela_convenio", "tipo_tabela", "status_tabela"]
].drop_duplicates().sort_values("convenio")
df_geral[["tipo_tabela", "descricao"]][
    df_geral["descricao"].str.contains("psia")
].drop_duplicates().sort_values("tipo_tabela")

# %%
col = [
    "especialidade",
    "procedimento_generico",
    "descricao",
]
df_proced = df_geral[col].copy()
print(len(df_proced))

df_proced.drop_duplicates(inplace=True)
print(len(df_proced))

df_proc_generico = df_proced["procedimento_generico"].copy()
df_proc_generico.drop_duplicates(inplace=True)
print(len(df_proc_generico))

df_proc_generico.isna().sum()

df_proced_nulos = df_proced[
    df_proced["procedimento_generico"].isna() | df_proced["especialidade"].isna()
].copy()


df_proced_encontrados = df_proced[
    ~df_proced.index.isin(list(df_proced_nulos.index))
].copy()
df_proced_encontrados.sample(7)

print(
    f"Qtd procedimento nulos {len(df_proced_nulos)} | Encontrados {len(df_proced_encontrados)}"
)
# Out:
# 14287
# 5039
# 278
# Qtd procedimento nulos 3368 | Encontrados 1671

# %%
def ptable(df, col, txt):
    df_ = df[df[col].str.casefold().str.contains(txt)]
    return pd.pivot_table(
        df_,
        index=[
            "especialidade",
            "procedimento_generico",
            "descricao",
            # "tabela_convenio",
        ],
        values=["descricao"],
        aggfunc="count",
    )


display_options(10, 7)
ptable(df_proced_encontrados, "descricao", "rest")

# %%
lista_procedimentos_errados = utils.import_list("lista_procedimentos_errados")

for i in lista_procedimentos_errados:
    print(
        f"""{
            df_proced_encontrados[
                df_proced_encontrados['descricao'] == i
            ].descricao.values
        } -> {
            df_proced_encontrados[
                df_proced_encontrados['descricao'] == i
            ].procedimento_generico.values
        }"""
    )

# drop
for i in lista_procedimentos_errados:
    df_proced_encontrados.drop(
        df_proced_encontrados[df_proced_encontrados["descricao"] == i].index,
        inplace=True,
    )

# atualizando
df_proced_nulos = df_proced[
    ~df_proced.index.isin(list(df_proced_encontrados.index))
].copy()

print("\n")
print("ATUALIZACAO TABELA PROCEDIMENTOS ENCONTRADOS")

for i in lista_procedimentos_errados:
    print(
        f"""{
            df_proced_encontrados[
                df_proced_encontrados['descricao'] == i
            ].descricao.values
        } -> {
            df_proced_encontrados[
                df_proced_encontrados['descricao'] == i
            ].procedimento_generico.values
        }"""
    )

print("\n")
print("PROCEDIMENTOS ADICIONADOS NA TABELA DE PROCEDIMENTOS A CORRIGIR")

for i in lista_procedimentos_errados:
    print(
        f"""{
            df_proced_nulos[
                df_proced_nulos['descricao'] == i
            ].descricao.values
        } -> {
            df_proced_nulos[
                df_proced_nulos['descricao'] == i
            ].procedimento_generico.values
        }"""
    )

utils.export_list(lista_procedimentos_errados, "lista_procedimentos_errados")
# Out:
# ['FIOS, PINOS, PARAFUSOS OU HASTES METALICOS INTRA-OSSEOS'] -> ['PRODUTOS: FIO DENTAL']
# ['FIOS OU PINOS METALICOS TRANSOSSEOS'] -> ['PRODUTOS: FIO DENTAL']
# ['RES. PINO'] -> ['RECONSTRUCAO DE DENTE COM PINO']
#
#
# ATUALIZACAO TABELA PROCEDIMENTOS ENCONTRADOS
# [] -> []
# [] -> []
# [] -> []
#
#
# PROCEDIMENTOS ADICIONADOS NA TABELA DE PROCEDIMENTOS A CORRIGIR
# ['FIOS, PINOS, PARAFUSOS OU HASTES METALICOS INTRA-OSSEOS'] -> ['PRODUTOS: FIO DENTAL']
# ['FIOS OU PINOS METALICOS TRANSOSSEOS'] -> ['PRODUTOS: FIO DENTAL']
# ['RES. PINO'] -> ['RECONSTRUCAO DE DENTE COM PINO']

# %%
df_proced_encontrados_correcao = (
    df_proced_encontrados[
        df_proced_encontrados["procedimento_generico"]
        .str.casefold()
        .str.contains("pino")
    ]
    .sort_values(by="procedimento_generico")
    .copy()
)

df_proced_encontrados_correcao
# Out:
#       especialidade      procedimento_generico  \
# 71          Protese  COROA PROVISORIA COM PINO
# 2317        Protese  COROA PROVISORIA COM PINO
# 6523        Protese  COROA PROVISORIA COM PINO
# 10675       Protese  COROA PROVISORIA COM PINO
# 1936        Protese  COROA PROVISORIA COM PINO
# ...             ...                        ...
# 1702     Dentistica       RESTAURACAO COM PINO
# 1300     Dentistica       RESTAURACAO COM PINO
# 181      Dentistica       RESTAURACAO COM PINO
# 5824     Dentistica       RESTAURACAO COM PINO
# 11289    Dentistica       RESTAURACAO COM PINO
#
#                                                descricao
# 71     Coroa unitária provisória c/ ou s/ pino prov. ...
# 2317   COROA UNITARIA PROVISORIA COM OU SEM PINO PROV...
# 6523                           COROA PROVISORIA COM PINO
# 10675                                    COR PROV C/PINO
# 1936                                  COROA PROV C/ PINO
# ...                                                  ...
# 1702                  RESTAURAÇÃO A PINO INTRADENTINARIO
# 1300                                  RESTAURAÇÃO A PINO
# 181                  Restauração a pino intra-dentinário
# 5824                                Restauração com Pino
# 11289                                RESTAURAÇÃO A PINO
#
# [29 rows x 3 columns]

# %% [markdown]
# Remover errados

# %%
df_proced_encontrados["procedimento_generico"].to_list()
# Out:
# ['CONSULTA ODONTOLOGICA',
#  'URGENCIA ODONTOLOGICA',
#  'URGENCIA ODONTOLOGICA',
#  'PULPOTOMIA',
#  'RECIMENTACAO DE TRABALHOS PROTETICOS',
#  'TRATAMENTO DE ALVEOLITE',
#  'COLAGEM DE FRAGMENTOS DENTARIOS',
#  'CONTROLE DE HEMORRAGIA',
#  'INCISAO E DRENAGEM EXTRA ORAL DE ABSCESSO, HEMATOMA E/OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'INCISAO E DRENAGEM INTRA ORAL DE ABSCESSO, HEMATOMA E/OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'REIMPLANTE DENTARIO COM CONTENCAO',
#  'CURATIVO DE DEMORA',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'APLICACAO DE CARIOSTATICO',
#  'ADEQUACAO DO MEIO BUCAL',
#  'REMINERALIZACAO',
#  'TESTE DE FLUXO SALIVAR',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'COROA DE ACETATO EM DENTE DECIDUO',
#  'EXODONTIA DE DECIDUOS',
#  'PULPOTOMIA',
#  'TRATAMENTO ENDODONTICO EM DENTE DECIDUO',
#  'EXODONTIA DE PERMANENTE',
#  'EXODONTIA DE RAIZ RESIDUAL',
#  'EXODONTIA A RETALHO',
#  'ODONTO-SECCAO',
#  'ALVEOLOPLASTIA',
#  'ALVEOLOPLASTIA',
#  'FRENULECTOMIA',
#  'FRENULECTOMIA',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'AUMENTO DE COROA CLINICA',
#  'ULECTOMIA',
#  'ALVEOLOPLASTIA',
#  'APICETOMIA UNIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA BIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA UNIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA BIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES COM OBTURACAO RETROGRADA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RESTAURACAO DE AMALGAMA - 4 FACES',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 1 FACE',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 2 FACES',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 3 FACES',
#  'CIRURGIA PARA TORUS MANDIBULAR – UNILATERAL',
#  'CIRURGIA PARA TORUS MANDIBULAR – BILATERAL',
#  'CIRURGIA PARA TORUS PALATINO',
#  'BRIDECTOMIA',
#  'EXERESE OU EXCISAO DE RANULA',
#  'EXERESE OU EXCISAO DE CISTOS ODONTOLOGICOS',
#  'COLETA DE RASPADO EM LESOES OU SITIOS ESPECIFICOS DA REGIAO BUCO-MAXILO-FACIAL',
#  'REDUCAO SIMPLES DE LUXACAO DA ATM',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU BUCO SINUSAIS',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO PARA TUMORES ODONTOGENICOS BENIGNOS - SEM RECONSTRUCAO',
#  'COROA PROVISORIA COM PINO',
#  'PINO PRE FABRICADO',
#  'COROA METALO CERAMICA',
#  'COROA TOTAL METALICA',
#  'COROA TOTAL EM CEROMERO',
#  'NUCLEO METALICO FUNDIDO',
#  'RESTAURACAO METALICA FUNDIDA',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'TRATAMENTO ENDODONTICO BIRRADICULAR',
#  'TRATAMENTO ENDODONTICO MULTIRADICULAR',
#  'TRATAMENTO ENDODONTICO UNIRADICULAR',
#  'FOTOGRAFIA',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE HERPETICA',
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE POR CANDIDOSE',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM MATERIAL DE BIOPSIA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO E TRATAMENTO DE XEROSTOMIA ',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'REDUCAO SIMPLES DE LUXACAO DA ATM',
#  'DOCUMENTACAO ORTODONTICA',
#  'RASPAGEM SUB-GENGIVAL',
#  'IMOBILIZACAO EM DENTES PERMANENTES',
#  'GENGIVECTOMIA',
#  'TUNELIZACAO',
#  'AUMENTO DE COROA CLINICA',
#  'GENGIVOPLASTIA',
#  'ENXERTO CONJUNTIVO SUBEPITELIAL',
#  'CIRURGIA PERIODONTAL A RETALHO',
#  'CUNHA PROXIMAL',
#  'ENXERTO GENGIVAL LIVRE',
#  'ENXERTO PEDICULADO',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'CONTENCAO ORTODONTICA',
#  'CONTENCAO ORTODONTICA',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'FACETA DIRETA EM RESINA FOTOPOLIMERIZAVEL',
#  'RETRATAMENTO ENDODONTICO BIRRADICULAR',
#  'RETRATAMENTO ENDODONTICO MULTIRADICULAR',
#  'ULOTOMIA',
#  'FRENULECTOMIA',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU BUCO SINUSAIS',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 4 FACES',
#  'AJUSTE OCLUSAL POR DESGASTE SELETIVO',
#  'NUCLEO DE PREENCHIMENTO',
#  'SEPULTAMENTO RADICULAR',
#  'PROTESE PARCIAL REMOVIVEL COM GRAMPOS',
#  'PROTESE TOTAL',
#  'PROTESE PARCIAL REMOVIVEL COM GRAMPOS',
#  'COROA PROVISORIA SEM PINO',
#  'RETRATAMENTO ENDODONTICO UNIRADICULAR',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'CONSULTA ODONTOLOGICA',
#  'CONSULTA ODONTOLOGICA',
#  'COLAGEM DE FRAGMENTOS DENTARIOS',
#  'CONTROLE DE HEMORRAGIA',
#  'CONTROLE DE HEMORRAGIA',
#  'CURATIVO DE DEMORA',
#  'IMOBILIZACAO EM DENTES PERMANENTES',
#  'IMOBILIZACAO DENTARIA EM DENTES DECIDUOS',
#  'INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'DRENABCESINTRA',
#  'RECIMENTACAO DE TRABALHOS PROTETICOS',
#  'REDUCAO SIMPLES DE LUXACAO DE ARTICULACAO TEMPORO- MANDIBULAR (ATM)',
#  'REIMPLANTE DENTARIO COM CONTENCAO',
#  'TRATAMENTO DE ABSCESSO PERIODONTAL AGUDO',
#  'TRATAMENTO DE ALVEOLITE',
#  'TRATAMENTO DE PERICORONARITE',
#  'CONSULTA ODONTOLOGICA INICIAL',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM CITOLOGIA ESFOLIATIVA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM MATERIAL DE BIOPSIA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PECA CIRURGICA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PUNCAO NA REGIAO BUCO-MAXILO-FACIAL',
#  'FOTOGRAFIA',
#  'RADIOGRAFIA PERIAPICAL',
#  'MODELOS ORTODONTICOS',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'REDUCAO SIMPLES DE LUXACAO DA ATM',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'CLAREAMENTO DENTARIO DE CONSULTORIO',
#  'CLAREAMENTO DENTARIO A LASER',
#  'FACETA DIRETA EM RESINA FOTOPOLIMERIZAVEL',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'RESTAURACAO COM PINO',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'APLICACAO DE CARIOSTATICO',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'APLICACAO TOPICA DE FLUOR',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'COROA DE ACETATO EM DENTE DECIDUO',
#  'COROA DE ACETATO EM DENTE PERMANENTE',
#  'COROA DE ACO EM DENTE DECIDUO',
#  'COROA DE ACO EM DENTE PERMANENTE',
#  'COROA DE POLICARBONATO EM DENTE DECIDUO',
#  'COROA DE POLICARBONATO EM DENTE PERMANENTE',
#  'EXODONTIA DE DECIDUOS',
#  'CONTENCAO ORTODONTICA',
#  'CONTENCAO ORTODONTICA',
#  'PULPOTOMIA',
#  'TRATAMENTO ENDODONTICO EM DENTE DECIDUO',
#  'REMOCAO DE NUCLEO INTRARRADICULAR',
#  'RETRATAMENTO ENDODONTICO BIRRADICULAR',
#  'RETRATAMENTO ENDODONTICO MULTIRADICULAR',
#  'RETRATAMENTO ENDODONTICO UNIRADICULAR',
#  'TRATAMENTO DE PERFURACAO ENDODONTICA',
#  'TRATAMENTO ENDODONTICO BIRRADICULAR',
#  'TRATAMENTO ENDODONTICO DE DENTE COM RIZOGENESE INCOMPLETA',
#  'TRATAMENTO ENDODONTICO MULTIRADICULAR',
#  'TRATAMENTO ENDODONTICO UNIRADICULAR',
#  'AUMENTO DE COROA CLINICA',
#  'CIRURGIA PERIODONTAL A RETALHO',
#  'CUNHA PROXIMAL',
#  'ENXERTO CONJUNTIVO SUBEPITELIAL',
#  'ENXERTO GENGIVAL LIVRE',
#  'ENXERTO PEDICULADO',
#  'PRODUTOS: FIO DENTAL',
#  'GENGIVECTOMIA',
#  'GENGIVOPLASTIA',
#  'IMPLANTE OSSEO INTEGRADO',
#  'RASPAGEM SUB-GENGIVAL',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BRIDECTOMIA',
#  'BRIDOTOMIA',
#  'CIRURGIA PARA EXOSTOSE MAXILAR',
#  'CIRURGIA PARA TORUS MANDIBULAR – BILATERAL',
#  'CIRURGIA PARA TORUS MANDIBULAR – UNILATERAL',
#  'CIRURGIA PARA TORUS PALATINO',
#  'EXERESE DE LIPOMA NA REGIAO BUCO-MAXILO-FACIAL',
#  'EXERESE OU EXCISAO DE CALCULO SALIVAR',
#  'EXERESE OU EXCISAO DE CISTOS ODONTOLOGICOS',
#  'EXERESE OU EXCISAO DE MUCOCELE',
#  'EXERESE OU EXCISAO DE RANULA',
#  'EXODONTIA A RETALHO',
#  'EXODONTIA DE PERMANENTE POR INDICACAO ORTODONTICA/PROTETICA',
#  'EXODONTIA DE RAIZ RESIDUAL',
#  'FRENULECTOMIA',
#  'FRENULECTOMIA',
#  'FRENULECTOMIA',
#  'FRENULECTOMIA',
#  'ODONTO-SECCAO',
#  'ALVEOLOPLASTIA',
#  'ALVEOLOPLASTIA',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'TRACIONAMENTO CIRURGICO COM FINALIDADE ORTODONTICA',
#  'TRATAMENTO CIRURGICO DE BRIDAS CONSTRITIVAS DA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO-NASAIS',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU BUCO SINUSAIS',
#  'TRATAMENTO CIRURGICO DE  HIPERPLASIAS DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO PARA TUMORES ODONTOGENICOS BENIGNOS - SEM RECONSTRUCAO',
#  'ULECTOMIA',
#  'ULOTOMIA',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'COROA TOTAL METALICA',
#  'COROA METALO CERAMICA',
#  'COROA METALO CERAMICA',
#  'DIAGNOSTICO POR MEIO DE ENCERAMENTO',
#  'FACETA EM CERAMICA PURA',
#  'FACETA EM CEROMERO',
#  'NUCLEO DE PREENCHIMENTO',
#  'NUCLEO METALICO FUNDIDO',
#  'PLACA MIORELAXANTE',
#  'ORTESE REPOSICIONADORA (PLACA OCLUSAL REPOSICIONADORA)',
#  'PLACA OCLUSAL RESILIENTE',
#  'PROTESE PARCIAL FIXA PROVISORIA',
#  'PROTESE ADESIVA EM CERAMICA',
#  'PROTESE FIXA ADESIVA INDIRETA EM METALO PLASTICA',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROTESE TOTAL',
#  'PROTESE TOTAL',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'APLICACAO TOPICA DE FLUOR',
#  'CONSULTA ODONTOLOGICA INICIAL',
#  'CONSULTA ODONTOLOGICA',
#  'CONSULTA ODONTOLOGICA',
#  'CONSULTA ODONTOLOGICA',
#  'DIAGNOSTICO E TRATAMENTO DE HALITOSE',
#  'DIAGNOSTICO E TRATAMENTO DE XEROSTOMIA ',
#  'ACOMPANHAMENTO DE PROCEDIMENTIO CIRURGICO',
#  'CONTROLE POS-OPERATORIO EM ODONTOLOGIA',
#  'CONSULTA ODONTOLOGICA',
#  'CONSULTA ODONTOLOGICA',
#  'ALVEOLOPLASTIA',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'EXERESE DE LIPOMA NA REGIAO BUCO-MAXILO-FACIAL',
#  'AUMENTO DE COROA CLINICA',
#  'COLETA DE RASPADO EM LESOES OU SITIOS ESPECIFICOS DA REGIAO BUCO-MAXILO-FACIAL',
#  'EXERESE OU EXCISAO DE CISTOS ODONTOLOGICOS',
#  'EXERESE OU EXCISAO DE MUCOCELE',
#  'EXERESE OU EXCISAO DE RANULA',
#  'ORIENTACAO DE HIGIENE BUCAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'REMOCAO DE ODONTOMA',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO-NASAIS',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU BUCO SINUSAIS',
#  'INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'EXERESE OU EXCISAO DE CALCULO SALIVAR',
#  'CIRURGIA PARA TORUS MANDIBULAR – UNILATERAL',
#  'CIRURGIA PARA TORUS MANDIBULAR – BILATERAL',
#  'REIMPLANTE DENTARIO COM CONTENCAO',
#  'ALVEOLOPLASTIA',
#  'ALVEOLOPLASTIA',
#  'CONTROLE DE HEMORRAGIA',
#  'CONTROLE DE HEMORRAGIA',
#  'SUTURA DE FERIDA EM REGIAO BUCO-MAXILO-FACIAL',
#  'GUIA CIRURGICO PARA IMPLANTE',
#  'ENXERTO OSSEO LIOFILIZADO',
#  'ENXERTO OSSEO AUTOGENO',
#  'ENXERTO OSSEO AUTOGENO',
#  'LEVANTAMENTO DO SEIO MAXILAR COM OSSO AUTOGENO',
#  'LEVANTAMENTO DO SEIO MAXILAR COM OSSO HOMOLOGO',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RESTAURACAO DE AMALGAMA - 4 FACES',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'RESTAURAÇAO EM DENTE DECIDUO',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 1 FACE',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 2 FACES',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 3 FACES',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 4 FACES',
#  'DESSENSIBILIZACAO DENTARIA',
#  'RESTAURACAO TEMPORARIA / TRATAMENTO EXPECTANTE',
#  'COROA DE ACETATO EM DENTE PERMANENTE',
#  'COROA DE ACO EM DENTE PERMANENTE',
#  'COROA DE POLICARBONATO EM DENTE PERMANENTE',
#  'TESTE DE PH SALIVAR',
#  'PULPOTOMIA',
#  'PULPOTOMIA',
#  'CLAREAMENTO DE DENTE DESVITALIZADO',
#  'APICETOMIA BIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA BIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'DRENABCESINTRA',
#  'TRATAMENTO ENDODONTICO EM DENTE DECIDUO',
#  'EXODONTIA DE DECIDUOS',
#  'ADEQUACAO DE MEIO BUCAL COM IONOMERO DE VIDRO)',
#  'ADEQUACAO DE MEIO BUCAL COM IONOMERO DE VIDRO)',
#  'ESTABILIZACAO DE PACIENTE POR MEIO DE CONTENCAO FISICA E/OU MECANICA',
#  'ORIENTACAO DE HIGIENE BUCAL',
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE HERPETICA',
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE POR CANDIDOSE',
#  'AMPUTACAO RADICULAR COM OBTURACAO RETROGRADA',
#  'AMPUTACAO RADICULAR SEM OBTURACAO RETROGRADA',
#  'TUNELIZACAO',
#  'APLICACAO TOPICA DE FLUOR',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'PINO PRE FABRICADO',
#  'COROA PROVISORIA SEM PINO',
#  'COROA TOTAL ACRILICA PRENSADA',
#  'RESTAURACAO METALICA FUNDIDA',
#  'COROA TOTAL METALICA',
#  'PROTESE PARCIAL REMOVIVEL COM GRAMPOS',
#  'AJUSTE OCLUSAL POR DESGASTE SELETIVO',
#  'AJUSTE OCLUSAL POR DESGASTE SELETIVO',
#  'REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL',
#  'REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL',
#  'RESTAURACAO EM CEROMERO - INLAY',
#  'RESTAURACAO EM CEROMERO - ONLAY',
#  'RESTAURACAO EM CERAMICA - INLAY',
#  'RESTAURACAO EM CERAMICA - ONLAY',
#  'COROA TOTAL EM CEROMERO',
#  'COROA METALO CERAMICA',
#  'COROA PROVISORIA',
#  'COROA PROVISORIA',
#  'COROA METALO CERAMICA',
#  'COROA METALO CERAMICA',
#  'PROTESE PARCIAL',
#  'OVERDENTURE BARRA CLIPE OU ORING SOBRE DOIS IMPLANTES',
#  'OVERDENTURE BARRA CLIPE OU ORING SOBRE TRES IMPLANTES',
#  'OVERDENTURE BARRA CLIPE OU ORING SOBRE QUATRO OU MAIS IMPLANTES',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'REDUCAO SIMPLES DE LUXACAO DA ATM',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'PRODUTOS: KIT ORTODONTICO',
#  'EXODONTIA DE RAIZ RESIDUAL',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'RASPAGEM SUB-GENGIVAL',
#  'ORIENTACAO DE HIGIENE BUCAL',
#  'EXODONTIA A RETALHO',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'TRATAMENTO ENDODONTICO UNIRADICULAR',
#  'CONSULTA ODONTOLOGICA INICIAL',
#  'CONSULTA ODONTOLOGICA',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM CITOLOGIA ESFOLIATIVA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM MATERIAL DE BIOPSIA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PECA CIRURGICA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PUNCAO NA REGIAO BUCO-MAXILO-FACIAL',
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE HERPETICA',
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE POR CANDIDOSE',
#  'DIAGNOSTICO E TRATAMENTO DE HALITOSE',
#  'DIAGNOSTICO E TRATAMENTO DE XEROSTOMIA ',
#  'APLICACAO TOPICA DE FLUOR',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'CONTROLE DE BIOFILME',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'CONTROLE DE BIOFILME',
#  'TESTE DE FLUXO SALIVAR',
#  'TESTE DE PH SALIVAR',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'TRATAMENTO DE MANUTENCAO PARA PERIODONTITE LEVE',
#  'PULPOTOMIA',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'FACETA DIRETA EM RESINA FOTOPOLIMERIZAVEL',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RESTAURACAO DE AMALGAMA - 4 FACES',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'RESTAURACAO TEMPORARIA / TRATAMENTO EXPECTANTE',
#  'APLICACAO DE CARIOSTATICO',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'CONTROLE DE CARIE INCIPIENTE',
#  'COROA DE ACETATO EM DENTE DECIDUO',
#  'COROA DE ACO EM DENTE DECIDUO',
#  'COROA DE POLICARBONATO EM DENTE DECIDUO',
#  'IMOBILIZACAO DENTARIA EM DENTES DECIDUOS',
#  'CONTENCAO ORTODONTICA',
#  'CONTENCAO ORTODONTICA',
#  'PULPOTOMIA',
#  'REMINERALIZACAO',
#  'RESTAURAÇAO EM DENTE DECIDUO',
#  'RESTAURACAO ATRAUMATICA EM DENTE PERMANENTE',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 1 FACE',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 2 FACES',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 3 FACES',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 4 FACES',
#  'TRATAMENTO ENDODONTICO EM DENTE DECIDUO',
#  'CLAREAMENTO DE DENTE DESVITALIZADO',
#  'PREPARO PARA NUCLEO INTRARRADICULAR',
#  'PULPOTOMIA',
#  'REMOCAO DE NUCLEO INTRARRADICULAR',
#  'RETRATAMENTO ENDODONTICO BIRRADICULAR',
#  'RETRATAMENTO ENDODONTICO UNIRADICULAR',
#  'TRATAMENTO DE PERFURACAO ENDODONTICA',
#  'TRATAMENTO ENDODONTICO DE DENTE COM RIZOGENESE INCOMPLETA',
#  'ACOMPANHAMENTO DE PROCEDIMENTIO CIRURGICO',
#  'AUMENTO DE COROA CLINICA',
#  'DESSENSIBILIZACAO DENTARIA',
#  'IMOBILIZACAO EM DENTES PERMANENTES',
#  'RASPAGEM SUB-GENGIVAL',
#  'TUNELIZACAO',
#  'AMPUTACAO RADICULAR COM OBTURACAO RETROGRADA',
#  'AMPUTACAO RADICULAR SEM OBTURACAO RETROGRADA',
#  'APICETOMIA BIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA BIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA UNIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA UNIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BRIDECTOMIA',
#  'BRIDOTOMIA',
#  'CIRURGIA ODONTOLOGICA COM APLICACAO DE ALOENXERTOS',
#  'CIRURGIA PARA EXOSTOSE MAXILAR',
#  'CIRURGIA PARA TORUS MANDIBULAR – BILATERAL',
#  'CIRURGIA PARA TORUS MANDIBULAR – UNILATERAL',
#  'CIRURGIA PARA TORUS PALATINO',
#  'EXERESE DE LIPOMA NA REGIAO BUCO-MAXILO-FACIAL',
#  'EXERESE OU EXCISAO DE CALCULO SALIVAR',
#  'EXERESE OU EXCISAO DE CISTOS ODONTOLOGICOS',
#  'EXERESE OU EXCISAO DE MUCOCELE',
#  'EXERESE OU EXCISAO DE RANULA',
#  'EXODONTIA DE PERMANENTE POR INDICACAO ORTODONTICA/PROTETICA',
#  'EXODONTIA DE RAIZ RESIDUAL',
#  'EXODONTIA DE PERMANENTE',
#  'FRENULECTOMIA',
#  'FRENULECTOMIA',
#  'FRENULECTOMIA',
#  'FRENULECTOMIA',
#  'ODONTO-SECCAO',
#  'PUNCAO ASPIRATIVA NA REGIAO BUCO-MAXILO-FACIAL',
#  'RECONSTRUCAO DE DENTE COM PINO',
#  'ALVEOLOPLASTIA',
#  'ALVEOLOPLASTIA',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'TRACIONAMENTO CIRURGICO COM FINALIDADE ORTODONTICA',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO-NASAIS',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU BUCO SINUSAIS',
#  'TRATAMENTO CIRURGICO DE BRIDAS CONSTRITIVAS DA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE  HIPERPLASIAS DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO PARA TUMORES ODONTOGENICOS BENIGNOS - SEM RECONSTRUCAO',
#  'ULECTOMIA',
#  'RADIOGRAFIA PERIAPICAL',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'EXODONTIA DE RAIZ RESIDUAL',
#  'EXODONTIA DE PERMANENTE',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'AJUSTE OCLUSAL POR DESGASTE SELETIVO',
#  'PULPOTOMIA',
#  'CONSULTA ODONTOLOGICA',
#  'CURATIVO DE DEMORA',
#  'RASPAGEM SUB-GENGIVAL',
#  'COLAGEM DE FRAGMENTOS DENTARIOS',
#  'RADIOGRAFIA PERIAPICAL',
#  'RADIOGRAFIA PERIAPICAL',
#  'TRATAMENTO DE ALVEOLITE',
#  'URGENCIA ODONTOLOGICA',
#  'CONSULTA ODONTOLOGICA INICIAL',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'CONSULTA ODONTOLOGICA',
#  'AUMENTO DE COROA CLINICA',
#  'GENGIVECTOMIA',
#  'GENGIVECTOMIA',
#  'RADIOGRAFIA PERIAPICAL',
#  'PULPOTOMIA',
#  'EXODONTIA DE DECIDUOS',
#  'ACOMPANHAMENTO DE PROCEDIMENTIO CIRURGICO',
#  'APICETOMIA BIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA UNIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA UNIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'BIOPSIA',
#  'CIRURGIA ODONTOLOGICA A RETALHO',
#  'CIRURGIA ODONTOLOGICA COM APLICACAO DE ALOENXERTOS',
#  'COLETA DE RASPADO EM LESOES OU SITIOS ESPECIFICOS DA REGIAO BUCO-MAXILO-FACIAL',
#  'ENXERTO CONJUNTIVO SUBEPITELIAL',
#  'IMPLANTE ORTODONTICO',
#  'IMPLANTE OSSEO INTEGRADO',
#  'IMPLANTE ZIGOMATICO',
#  'INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'LEVANTAMENTO DO SEIO MAXILAR COM OSSO LIOFILIZADO',
#  'PUNCAO ASPIRATIVA NA REGIAO BUCO-MAXILO-FACIAL',
#  'RECONSTRUCAO DE DENTE COM PINO',
#  'REDUCAO SIMPLES DE LUXACAO DE ARTICULACAO TEMPORO- MANDIBULAR (ATM)',
#  'SEPULTAMENTO RADICULAR',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO-NASAIS',
#  'TRATAMENTO CIRURGICO DE  HIPERPLASIAS DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO PARA TUMORES ODONTOGENICOS BENIGNOS - SEM RECONSTRUCAO',
#  'IMPLANTE OSSEO INTEGRADO',
#  'EXODONTIA DE RAIZ RESIDUAL',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'ACOMPANHAMENTO DE PROCEDIMENTIO CIRURGICO',
#  'ALVEOLOPLASTIA',
#  'AMPUTACAO RADICULAR COM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA UNIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA UNIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'CIRURGIA PARA TORUS MANDIBULAR – UNILATERAL',
#  'EXODONTIA DE PERMANENTE POR INDICACAO ORTODONTICA/PROTETICA',
#  'ALVEOLOPLASTIA',
#  'ALVEOLOPLASTIA',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO PARA TUMORES ODONTOGENICOS BENIGNOS - SEM RECONSTRUCAO',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RESTAURACAO DE AMALGAMA - 4 FACES',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'AJUSTE OCLUSAL POR DESGASTE SELETIVO',
#  'RADIOGRAFIA PERIAPICAL',
#  'TRATAMENTO ENDODONTICO EM DENTE DECIDUO',
#  'PULPOTOMIA',
#  'COROA TOTAL METALICA',
#  'COROA METALO CERAMICA',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'CLAREAMENTO DENTARIO A LASER',
#  'COROA DE ACO EM DENTE DECIDUO',
#  'PULPOTOMIA',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RESTAURACAO DE AMALGAMA - 4 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'ARCO LINGUAL',
#  'PISTAS DIRETAS DE PLANAS SUPERIOR E/OU INFERIOR',
#  'RASPAGEM SUB-GENGIVAL',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'RASPAGEM SUB-GENGIVAL',
#  'TRATAMENTO DE ABSCESSO PERIODONTAL AGUDO',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'APLICACAO TOPICA DE FLUOR',
#  'CONTROLE DE BIOFILME',
#  'ADEQUACAO DO MEIO BUCAL',
#  'RESTAURACAO TEMPORARIA / TRATAMENTO EXPECTANTE',
#  'DIAGNOSTICO POR MEIO DE ENCERAMENTO',
#  'RESTAURACAO EM RESINA INDIRETA - INLAY',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'COROA PROVISORIA COM PINO',
#  'COROA PROVISORIA SEM PINO',
#  'COROA TOTAL ACRILICA PRENSADA',
#  'COROA TOTAL EM CERAMICA PURA',
#  'COROA TOTAL EM CEROMERO',
#  'COROA TOTAL METALICA',
#  'COROA METALO CERAMICA',
#  'FACETA EM CERAMICA PURA',
#  'GUIA CIRURGICO PARA PROTESE TOTAL IMEDIATA',
#  'NUCLEO DE PREENCHIMENTO',
#  'NUCLEO METALICO FUNDIDO',
#  'RESTAURACAO EM RESINA INDIRETA - ONLAY',
#  'PLACA MIORELAXANTE',
#  'PINO PRE FABRICADO',
#  'PROTESE ADESIVA EM CERAMICA',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL REMOVIVEL COM GRAMPOS',
#  'PROTESE PARCIAL REMOVIVEL COM GRAMPOS',
#  'PROTESE TOTAL',
#  'PROTESE TOTAL',
#  'PROTESE TOTAL',
#  'REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL',
#  'REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL',
#  'REMOCAO DE TRABALHOS PROTETICOS',
#  'RESTAURACAO EM CERAMICA - INLAY',
#  'RESTAURACAO EM CERAMICA - ONLAY',
#  'RESTAURACAO EM CEROMERO - ONLAY',
#  'RESTAURACAO EM CEROMERO - INLAY',
#  'RESTAURACAO METALICA FUNDIDA',
#  'PROTESE TOTAL',
#  'REIMPLANTE DENTARIO COM CONTENCAO',
#  'COLAGEM DE FRAGMENTOS DENTARIOS',
#  'TRATAMENTO DE PERICORONARITE',
#  'RECIMENTACAO DE TRABALHOS PROTETICOS',
#  'CONTROLE DE HEMORRAGIA',
#  'INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'DRENABCESINTRA',
#  'COROA PROVISORIA',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'APICETOMIA BIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA BIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'BIOPSIA',
#  'CIRURGIA ODONTOLOGICA A RETALHO',
#  'CIRURGIA PARA TORUS MANDIBULAR – BILATERAL',
#  'COLETA DE RASPADO EM LESOES OU SITIOS ESPECIFICOS DA REGIAO BUCO-MAXILO-FACIAL',
#  'CONTROLE DE HEMORRAGIA',
#  'ODONTO-SECCAO',
#  'PUNCAO ASPIRATIVA NA REGIAO BUCO-MAXILO-FACIAL',
#  'ORIENTACAO DE HIGIENE BUCAL',
#  'REMOCAO DE ODONTOMA',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO-NASAIS',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU BUCO SINUSAIS',
#  'TRATAMENTO CIRURGICO DE  HIPERPLASIAS DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'MARSUPIALIZACAO DE CISTOS ODONTOLOGICOS',
#  'CURETAGEM APICAL',
#  'EXODONTIA DE RAIZ RESIDUAL',
#  'CONSULTA ODONTOLOGICA',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM CITOLOGIA ESFOLIATIVA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM MATERIAL DE BIOPSIA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PECA CIRURGICA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PUNCAO NA REGIAO BUCO-MAXILO-FACIAL',
#  'DIAGNOSTICO E PLANEJAMENTO PARA TRATAMENTO ODONTOLOGICO',
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE HERPETICA',
#  'DIAGNOSTICO POR MEIO DE descricaoS LABORATORIAIS',
#  'IMPLANTE ORTODONTICO',
#  'TESTE DE PH SALIVAR',
#  'APLICACAO DE LASER TERAPEUTICO',
#  'COROA DE POLICARBONATO EM DENTE DECIDUO',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'APLICACAO TOPICA DE FLUOR',
#  'CONTROLE POS-OPERATORIO EM ODONTOLOGIA',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'AMPUTACAO RADICULAR SEM OBTURACAO RETROGRADA',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'TRATAMENTO ENDODONTICO MULTIRADICULAR',
#  'EXERESE OU EXCISAO DE CISTOS ODONTOLOGICOS',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO-NASAIS',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL',
#  'REDUCAO SIMPLES DE LUXACAO DE ARTICULACAO TEMPORO- MANDIBULAR (ATM)',
#  'DRENABCESINTRA',
#  'CURATIVO DE DEMORA',
#  'TRATAMENTO ENDODONTICO DE DENTE COM RIZOGENESE INCOMPLETA',
#  'COROA METALO CERAMICA',
#  'IMPLANTE OSSEO INTEGRADO',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'RASPAGEM SUB-GENGIVAL',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'COROA TOTAL EM CEROMERO',
#  'COROA METALO CERAMICA',
#  'COROA TOTAL METALICA',
#  'PROTESE FIXA ADESIVA INDIRETA EM METALO PLASTICA',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROVISORIO PARA FACETA',
#  'PROVISORIO PARA INLAY/ONLAY',
#  'RESTAURACAO EM RESINA INDIRETA - ONLAY',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'CONSULTA ODONTOLOGICA',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'EXODONTIA A RETALHO',
#  'RASPAGEM SUB-GENGIVAL',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RETRATAMENTO ENDODONTICO BIRRADICULAR',
#  'TRATAMENTO ENDODONTICO BIRRADICULAR',
#  'RADIOGRAFIA PERIAPICAL',
#  'CONSULTA ODONTOLOGICA',
#  'BIOPSIA',
#  'APICETOMIA BIRRADICULARES COM OBTURACAO RETROGRADA',
#  'APICETOMIA BIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'APICETOMIA MULTIRRADICULARES COM OBTURACAO RETROGRADA',
#  'EXODONTIA DE DECIDUOS',
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA',
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA',
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA',
#  'CONSULTA ODONTOLOGICA',
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA',
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA',
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA',
#  'TESTE DE PH SALIVAR',
#  'CONTROLE DE BIOFILME',
#  'ADEQUACAO DO MEIO BUCAL',
#  'PULPOTOMIA',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'CLAREAMENTO DENTARIO DE CONSULTORIO',
#  'RESTAURACAO COM PINO',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RESTAURACAO DE AMALGAMA - 4 FACES',
#  'RASPAGEM SUB-GENGIVAL',
#  'APICETOMIA MULTIRRADICULARES SEM OBTURACAO RETROGRADA',
#  'AUMENTO DE COROA CLINICA',
#  'BIOPSIA',
#  'DRENABCESINTRA',
#  'INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'PUNCAO ASPIRATIVA NA REGIAO BUCO-MAXILO-FACIAL',
#  'REDUCAO SIMPLES DE LUXACAO DE ARTICULACAO TEMPORO- MANDIBULAR (ATM)',
#  'TRATAMENTO CIRURGICO DE  HIPERPLASIAS DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO DE ALVEOLITE',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'CONSERTO EM PROTESE TOTAL / PARCIAL',
#  'COROA METALO CERAMICA',
#  'COROA TOTAL EM CEROMERO',
#  'COROA TOTAL METALICA',
#  'PLACA MIORELAXANTE',
#  'PROTESE FIXA ADESIVA INDIRETA EM METALO PLASTICA',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'PROTESE PARCIAL',
#  'REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL',
#  'REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL',
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA',
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA',
#  'REDUCAO SIMPLES DE LUXACAO DA ATM',
#  'MODELOS ORTODONTICOS',
#  'RADIOGRAFIA PERIAPICAL',
#  'RESTAURACAO EM CEROMERO - ONLAY',
#  'RESTAURACAO EM CEROMERO - INLAY',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'APLICACAO TOPICA DE FLUOR',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'TRATAMENTO DE MANUTENCAO PARA PERIODONTITE MODERADA',
#  'EXODONTIA DE PERMANENTE',
#  'APLICACAO TOPICA DE FLUOR',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'RASPAGEM SUB-GENGIVAL',
#  'RESTAURAÇAO EM DENTE DECIDUO',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'RETRATAMENTO ENDODONTICO BIRRADICULAR',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'APLICACAO TOPICA DE FLUOR',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'CONSULTA ODONTOLOGICA',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM CITOLOGIA ESFOLIATIVA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM MATERIAL DE BIOPSIA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PECA CIRURGICA NA REGIAO BUCO-MAXILO-FACIAL ',
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PUNCAO NA REGIAO BUCO-MAXILO-FACIAL',
#  'CONSULTA ODONTOLOGICA',
#  'CONTROLE DE HEMORRAGIA COM APLICACAO DE AGENTE',
#  'CONTROLE DE HEMORRAGIA SEM APLICACAO DE AGENTE',
#  'INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'DRENABCESINTRA',
#  'RECIMENTACAO DE TRABALHOS PROTETICOS',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'REMINERALIZACAO',
#  'TESTE DE PH SALIVAR',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 1 FACE',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 2 FACES',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 3 FACES',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 4 FACES',
#  'PISTAS DIRETAS DE PLANAS SUPERIOR E/OU INFERIOR',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'CONDICIONAMENTO EM ODONTOLOGIA',
#  'ESTABILIZACAO DE PACIENTE POR MEIO DE CONTENCAO FISICA E/OU MECANICA',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RESTAURACAO DE AMALGAMA - 4 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'RASPAGEM SUB-GENGIVAL',
#  'REDUCAO SIMPLES DE LUXACAO DE ARTICULACAO TEMPORO- MANDIBULAR (ATM)',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'TRATAMENTO DE MANUTENCAO PARA PERIODONTITE GRAVE',
#  'TRATAMENTO ENDODONTICO BIRRADICULAR',
#  'TRATAMENTO ENDODONTICO MULTIRADICULAR',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'RETRATAMENTO ENDODONTICO BIRRADICULAR',
#  'CIRURGIA PARA TORUS MANDIBULAR – BILATERAL',
#  'CIRURGIA PARA TORUS MANDIBULAR – UNILATERAL',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'PULPOTOMIA',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'TRATAMENTO DE PERIOD. DE MANUT. P/ PERIODONTITE LEVE 6 EM 6 MESES',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'TRATAMENTO DE MANUTENCAO PARA PERIODONTITE GRAVE',
#  'TRATAMENTO DE MANUTENCAO PARA PERIODONTITE LEVE',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'RESTAURACAO COM PINO',
#  'PREPARO PARA NUCLEO INTRARRADICULAR',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'CONSULTA ODONTOLOGICA',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'TRACIONAMENTO CIRURGICO COM FINALIDADE ORTODONTICA',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'EXODONTIA DE PERMANENTE POR INDICACAO ORTODONTICA/PROTETICA',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'CONSULTA ODONTOLOGICA',
#  'ORIENTACAO DE HIGIENE BUCAL',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'URGENCIA ODONTOLOGICA',
#  'MANUTENCAO ORTODONTICA GENERICA',
#  'EXODONTIA DE PERMANENTE POR INDICACAO ORTODONTICA/PROTETICA',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'RADIOGRAFIA PERIAPICAL',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'ORIENTACAO DE HIGIENE BUCAL',
#  'DESSENSIBILIZACAO DENTARIA',
#  'ORIENTACAO DE HIGIENE BUCAL',
#  'CONTROLE DE BIOFILME',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'APLICACAO TOPICA DE FLUOR',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#  'EXODONTIA DE DECIDUOS',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'RASPAGEM SUB-GENGIVAL',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'EXODONTIA A RETALHO',
#  'PLANEJAMENTO DE TRATAMENTO ORTODONTICO',
#  'RASPAGEM SUB-GENGIVAL',
#  'DESSENSIBILIZACAO DENTARIA',
#  'DESSENSIBILIZACAO DENTARIA',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RASPAGEM SUB-GENGIVAL',
#  'CONSULTA ODONTOLOGICA',
#  'RESTAURACAO EM IONOMERO DE VIDRO - 1 FACE',
#  'ORIENTACAO DE HIGIENE BUCAL',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'RADIOGRAFIA PERIAPICAL',
#  'COROA PROVISORIA',
#  'COROA PROVISORIA COM PINO',
#  'DIAGNOSTICO E PLANEJAMENTO PARA TRATAMENTO ODONTOLOGICO',
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE POR CANDIDOSE',
#  'DIAGNOSTICO POR MEIO DE descricaoS LABORATORIAIS',
#  'TRATAMENTO ENDODONTICO DE DENTE COM RIZOGENESE INCOMPLETA',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'TRATAMENTO DA ARTICULACAO TEMPOROMANDIBULAR ATM',
#  'RESTAURACAO ATRAUMATICA EM DENTE PERMANENTE',
#  'RESTAURACAO DE AMALGAMA - 1 FACE',
#  'RESTAURACAO DE AMALGAMA - 2 FACES',
#  'RESTAURACAO DE AMALGAMA - 3 FACES',
#  'RESTAURACAO DE AMALGAMA - 4 FACES',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'PREPARO PARA NUCLEO INTRARRADICULAR',
#  'RESTAURACAO COM PINO',
#  'RESTAURACAO COM PINO',
#  'RESTAURACAO COM PINO',
#  'CLAREAMENTO DENTARIO CASEIRO',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'CONSULTA ODONTOLOGICA INICIAL',
#  'RESTAURACAO EM RESINA 1 FACE',
#  'RESTAURACAO EM RESINA 2 FACES',
#  'RESTAURACAO EM RESINA 3 FACES',
#  'RESTAURACAO EM RESINA 4 FACES',
#  'EXODONTIA DE DECIDUOS',
#  'EXODONTIA SIMPLES DE PERMANENTE',
#  'CURATIVO DE DEMORA',
#  'CURATIVO DE DEMORA',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'COROA DE ACETATO EM DENTE DECIDUO',
#  'CONSULTA ODONTOLOGICA',
#  'EXODONTIA DE PERMANENTE POR INDICACAO ORTODONTICA/PROTETICA',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS',
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL',
#  'DRENABCESINTRA',
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#  'TRATAMENTO CIRURGICO PARA TUMORES ODONTOGENICOS BENIGNOS - SEM RECONSTRUCAO',
#  'EXODONTIA DE INCLUSOS / IMPACTADOS / SUPRANUMERARIO',
#  'RADIOGRAFIA PERIAPICAL',
#  'RASPAGEM SUB-GENGIVAL',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'CONSULTA ODONTOLOGICA',
#  'CONSULTA ODONTOLOGICA INICIAL',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'PROFILAXIA E POLIMENTO CORONARIO',
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE',
#  'TRATAMENTO ENDODONTICO EM DENTE DECIDUO',
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#  'APLICACAO TOPICA DE FLUOR',
#  ...]

# %%
# folder
pickle_path = "../ciadosorriso_metabase/data/pickle/"
csv_path = "data/db/csv/"
filename_pkl = f"{data_conciliacao_convenios}_database_panda_engine_atendimento_itens_generico_completo.pkl"
file_path_ati = f"{pickle_path}{filename_pkl}"
if os.path.exists(file_path_ati):
    print(f"\n🟢 Arquivo {file_path_ati} encontrado.")
    df_original_ = pd.read_pickle(file_path_ati)
else:
    print(f"\n⛔️ Arquivo {file_path_ati} não encontrado.")

# %%
df_geral["procedimento_generico"]
# Out:
# 0                         CONSULTA ODONTOLOGICA
# 1                         URGENCIA ODONTOLOGICA
# 2                         URGENCIA ODONTOLOGICA
# 3                                    PULPOTOMIA
# 4          RECIMENTACAO DE TRABALHOS PROTETICOS
#                           ...
# 14282    AVALIACAO ODONTOLOGICA ESTETICA FACIAL
# 14283        AVALIACAO ODONTOLOGICA PERIODONTIA
# 14284               AVALIACAO ODONTOLOGICA KIDS
# 14285                                       NaN
# 14286                                       NaN
# Name: procedimento_generico, Length: 14287, dtype: object

# %%
display_options()
display(
    df_geral[df_geral["descricao"].str.casefold().str.contains("psia")][
        ["descricao", "procedimento_generico"]
    ].drop_duplicates()
)
# Out:
#                                               descricao  \
# 41                                      Biópsia de Boca
# 42                          Biópsia de Glândula Salivar
# 43                                     Biópsia de Lábio
# ...                                                 ...
# 5631                               BIOPSIA DE EPIDIDIMO
# 6246                        BIOPSIA DE GLANDULA SALIVAR
# 9027  OMOPATOLOGICO DE MATERIAL DE BIOPSIA BUCO MAXI...
#
#                                   procedimento_generico
# 41                                              BIOPSIA
# 42                                              BIOPSIA
# 43                                              BIOPSIA
# ...                                                 ...
# 5631                                            BIOPSIA
# 6246                                            BIOPSIA
# 9027  DIAGNOSTICO ANATOMOPATOLOGICO EM MATERIAL DE B...
#
# [111 rows x 2 columns]

# %%
len(competitor_products)
# Out:
# 5032

# %%
# Sample data from our company and competitors

lista_proced_generico_adicionar = [
    "BIOPSIA DE BOCA"
    "BIOPSIA DE LABIO"
    "BIOPSIA DE LINGUA"
    "BIOPSIA DE MANDIBULA"
    "BIOPSIA DE MAXILA"
    "BIOPSIA DE GLANDULA SALIVAR"
]

our_products = (
    df_proced_encontrados["procedimento_generico"].drop_duplicates().to_list()
) + lista_proced_generico_adicionar

competitor_products = df_geral["descricao"].drop_duplicates().to_list()

# Mapping our products with competitor products using fuzzy matching
mapped_products = {}
for our_product in our_products:
    best_match_index, similarity_score = find_most_similar_product(
        our_product, competitor_products
    )

    mapped_products[our_product] = (
        competitor_products[best_match_index],
        similarity_score,
    )

# Displaying the mapped products
print("Product Mapping:")
for our_product, (competitor_product, similarity_score) in mapped_products.items():
    print(f"{our_product} => {competitor_product} (Similarity: {similarity_score})")
# Out:
# Product Mapping:
# CONSULTA ODONTOLOGICA => CONSULTA ODONTOLOGICA (Similarity: 100)
# URGENCIA ODONTOLOGICA => CONSULTA ODONTOLOGICA - URGENCIA (Similarity: 82)
# PULPOTOMIA => Pulpotomia (Similarity: 100)
# RECIMENTACAO DE TRABALHOS PROTETICOS => RECIMENTAÇÃO DE TRABALHOS PROTÉTICOS (Similarity: 96)
# TRATAMENTO DE ALVEOLITE => Tratamento de Alveolite (Similarity: 100)
# COLAGEM DE FRAGMENTOS DENTARIOS => Colagem de fragmentos dentários (Similarity: 98)
# CONTROLE DE HEMORRAGIA => HEMACIAS CONTAGEM DE (Similarity: 71)
# INCISAO E DRENAGEM EXTRA ORAL DE ABSCESSO, HEMATOMA E/OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL => Incisão e Drenagem extra-oral de abscesso, hematoma e/ou flegmão da
# região buco-maxilo-facial (Similarity: 98)
# INCISAO E DRENAGEM INTRA ORAL DE ABSCESSO, HEMATOMA E/OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL => Incisão e Drenagem intra-oral de abscesso, hematoma e/ou flegmão da região buco-maxilo-facial (Similarity: 98)
# REIMPLANTE DENTARIO COM CONTENCAO => REIMPLANTE DENTARIO COM CONTENÇAO (Similarity: 98)
# CURATIVO DE DEMORA => EMER-CURATIVO (Similarity: 77)
# APLICACAO DE SELANTE DE FOSSULAS E FISSURAS => APLICACAO DE SELANTE DE FOSSULAS E FISSURAS (Similarity: 100)
# APLICACAO DE CARIOSTATICO => Aplicação de Cariostático (Similarity: 94)
# ADEQUACAO DO MEIO BUCAL => Adequação do meio bucal (Similarity: 95)
# REMINERALIZACAO => REMINERALIZAÇAO (Similarity: 97)
# TESTE DE FLUXO SALIVAR => Teste de fluxo salivar (Similarity: 100)
# CONDICIONAMENTO EM ODONTOLOGIA => Condicionamento em Odontologia  (Similarity: 100)
# COROA DE ACETATO EM DENTE DECIDUO => Coroa de acetato em dente decíduo (Similarity: 98)
# EXODONTIA DE DECIDUOS => EXODONTIA DE DECIDUOS (Similarity: 100)
# TRATAMENTO ENDODONTICO EM DENTE DECIDUO => TRATAMENTO ENDODONTICO EM DENTE DECIDUO (Similarity: 100)
# EXODONTIA DE PERMANENTE => EXODONTIA DE DENTE PERMANENTE (Similarity: 88)
# EXODONTIA DE RAIZ RESIDUAL => Exodontia de Raiz Residual (Similarity: 100)
# EXODONTIA A RETALHO => Exodontia a Retalho (Similarity: 100)
# ODONTO-SECCAO => Odonto-secção (Similarity: 92)
# ALVEOLOPLASTIA => Alveoloplastia  (Similarity: 100)
# FRENULECTOMIA => Ulectomia   (Similarity: 82)
# EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO => EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS (Similarity: 83)
# EXODONTIA DE INCLUSOS / IMPACTADOS => EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS (Similarity: 93)
# AUMENTO DE COROA CLINICA => AUMENTO DE COROA CLINICA (Similarity: 100)
# ULECTOMIA => Ulectomia   (Similarity: 100)
# APICETOMIA UNIRRADICULARES SEM OBTURACAO RETROGRADA => APICETOMIA UNIRRADICULARES SEM OBTURAÇAO RETROGRADA (Similarity: 99)
# APICETOMIA BIRRADICULARES SEM OBTURACAO RETROGRADA => APICETOMIA BIRRADICULARES SEM OBTURAÇAO RETROGRADA (Similarity: 99)
# APICETOMIA MULTIRRADICULARES SEM OBTURACAO RETROGRADA => APICETOMIA MULTIRRADICULARES SEM OBTURAÇAO RETROGRADA (Similarity: 99)
# APICETOMIA UNIRRADICULARES COM OBTURACAO RETROGRADA => APICETOMIA UNIRRADICULARES COM OBTURAÇAO RETROGRADA (Similarity: 99)
# APICETOMIA BIRRADICULARES COM OBTURACAO RETROGRADA => APICETOMIA BIRRADICULARES COM OBTURAÇAO RETROGADA (Similarity: 98)
# APICETOMIA MULTIRRADICULARES COM OBTURACAO RETROGRADA => APICETOMIA MULTIRRADICULARES COM OBTURAÇAO RETROGRADA (Similarity: 99)
# BIOPSIA => BIOPSIA (Similarity: 100)
# RESTAURACAO DE AMALGAMA - 1 FACE => RESTAURACAO DE AMALGAMA 1 FACE (Similarity: 100)
# RESTAURACAO DE AMALGAMA - 2 FACES => RESTAURACAO DE AMALGAMA 2 FACES (Similarity: 100)
# RESTAURACAO DE AMALGAMA - 3 FACES => RESTAURACAO DE AMALGAMA 3 FACES  (Similarity: 100)
# RESTAURACAO DE AMALGAMA - 4 FACES => RESTAURACAO DE AMALGAMA 4 FACES (Similarity: 100)
# RESTAURACAO EM RESINA 1 FACE => RESTAURACAO EM RESINA 1 FACE  (Similarity: 100)
# RESTAURACAO EM RESINA 2 FACES => RESTAURACAO EM RESINA 2 FACES (Similarity: 100)
# RESTAURACAO EM RESINA 3 FACES => RESTAURACAO EM RESINA 3 FACES  (Similarity: 100)
# RESTAURACAO EM RESINA 4 FACES => RESTAURACAO EM RESINA 4 FACES  (Similarity: 100)
# RESTAURACAO EM IONOMERO DE VIDRO - 1 FACE => RETAURAÇAO EM IONOMERO DE VIDRO 1 FACE (Similarity: 97)
# RESTAURACAO EM IONOMERO DE VIDRO - 2 FACES => Restauração em ionômero de vidro 2 faces (Similarity: 96)
# RESTAURACAO EM IONOMERO DE VIDRO - 3 FACES => Restauração em ionômero de vidro 3 faces (Similarity: 96)
# CIRURGIA PARA TORUS MANDIBULAR – UNILATERAL => Cirurgia para torus mandibular - unilateral (Similarity: 100)
# CIRURGIA PARA TORUS MANDIBULAR – BILATERAL => Cirurgia para torus mandibular - bilateral (Similarity: 100)
# CIRURGIA PARA TORUS PALATINO => Cirurgia para torus palatino (Similarity: 100)
# BRIDECTOMIA => Bridectomia (Similarity: 100)
# EXERESE OU EXCISAO DE RANULA => Exerese ou excisão de rânula (Similarity: 96)
# EXERESE OU EXCISAO DE CISTOS ODONTOLOGICOS => EXERESE OU EXCISAO DE CISTO ODONTOLOGICO (Similarity: 98)
# COLETA DE RASPADO EM LESOES OU SITIOS ESPECIFICOS DA REGIAO BUCO-MAXILO-FACIAL => Coleta de raspado em lesões ou sítios específicos da região buco-maxilo-facial (Similarity: 97)
# REDUCAO SIMPLES DE LUXACAO DA ATM => REDUCAO DE LUXACAO DA ATM (Similarity: 86)
# TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU BUCO SINUSAIS => TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU SINUSAIS (Similarity: 96)
# TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL => TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL (Similarity: 91)
# TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL => Tratamento cirúrgico dos tumores benignos de tecidos moles na região
# buco-maxilo-facial (Similarity: 90)
# TRATAMENTO CIRURGICO PARA TUMORES ODONTOGENICOS BENIGNOS - SEM RECONSTRUCAO => Tratamento cirúrgico para tumores benignos odontogênicos - sem reconstrução (Similarity: 97)
# COROA PROVISORIA COM PINO => COROA PROVISORIA COM PINO (Similarity: 100)
# PINO PRE FABRICADO => Pino Pré Fabricado (Similarity: 97)
# COROA METALO CERAMICA => Coroa metalo-cerâmica (Similarity: 98)
# COROA TOTAL METALICA => COROA TOTAL METALICA (Similarity: 100)
# COROA TOTAL EM CEROMERO => COROA TOTAL EM CEROMERO (Similarity: 100)
# NUCLEO METALICO FUNDIDO => Núcleo metálico fundido (Similarity: 95)
# RESTAURACAO METALICA FUNDIDA => Restauração metálica fundida (Similarity: 94)
# PROFILAXIA E POLIMENTO CORONARIO => PROFILAXIA POLIMENTO CORONARIO (Similarity: 97)
# RADIOGRAFIA PERIAPICAL => Radiografia Periapical (Similarity: 100)
# RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE => TRATAMENTO DE GENGIVITE NECROSANTE AGUDA GNA (Similarity: 67)
# TRATAMENTO ENDODONTICO BIRRADICULAR => TRATAMENTO ENDODONTICO BIRRADICULAR (Similarity: 100)
# TRATAMENTO ENDODONTICO MULTIRADICULAR => TRATAMENTO ENDODONTICO MULTIRADICULAR (Similarity: 100)
# TRATAMENTO ENDODONTICO UNIRADICULAR => TRATAMENTO ENDODONTICO UNIRRADICULAR (Similarity: 99)
# FOTOGRAFIA => FOTOGRAFIA (Similarity: 100)
# DIAGNOSTICO E TRATAMENTO DE ESTOMATITE HERPETICA => DIAGNOSTICO E TRATAMENTO DE ESTOMATITE HERPETICA (Similarity: 100)
# DIAGNOSTICO E TRATAMENTO DE ESTOMATITE POR CANDIDOSE => Diagnóstico e tratamento de estomatite por candidose (Similarity: 99)
# DIAGNOSTICO ANATOMOPATOLOGICO EM MATERIAL DE BIOPSIA NA REGIAO BUCO-MAXILO-FACIAL  => Diagnóstico anatomopatológico em material de biópsia na região buco-maxilo-facial (Similarity: 97)
# DIAGNOSTICO E TRATAMENTO DE XEROSTOMIA  => DIAGNOSTICO E TRATAMENTO DE XEROSTOMIA (Similarity: 100)
# DOCUMENTACAO ORTODONTICA => DOCUMENTACAO ORTODONTICA (Similarity: 100)
# RASPAGEM SUB-GENGIVAL => RASPAGEM SUB GENGIVAL (Similarity: 100)
# IMOBILIZACAO EM DENTES PERMANENTES => IMOBILIZACAO DENTARIA EM DENTES PERMANENTES (Similarity: 88)
# GENGIVECTOMIA => GENGIVECTOMIA (Similarity: 100)
# TUNELIZACAO => TUNELIZACAO (Similarity: 100)
# GENGIVOPLASTIA => GENGIVOPLASTIA (Similarity: 100)
# ENXERTO CONJUNTIVO SUBEPITELIAL => ENXERTO CONJUNTIVO SUBEPITELIAL (Similarity: 100)
# CIRURGIA PERIODONTAL A RETALHO => CIRURGIA PERIODONTAL A RETALHO (Similarity: 100)
# CUNHA PROXIMAL => CUNHA PROXIMAL (Similarity: 100)
# ENXERTO GENGIVAL LIVRE => ENXERTO GENGIVAL LIVRE (Similarity: 100)
# ENXERTO PEDICULADO => ENXERTO PEDICULADO (Similarity: 100)
# MANUTENCAO ORTODONTICA GENERICA => MANUTENCAO APARELHO ORTODONTICO FIXO (Similarity: 72)
# CONTENCAO ORTODONTICA => Cera Ortodontica (Similarity: 81)
# FACETA DIRETA EM RESINA FOTOPOLIMERIZAVEL => FACETA DIRETA EM RESINA FOTOPOLIMERIZAVEL (Similarity: 100)
# RETRATAMENTO ENDODONTICO BIRRADICULAR => RETRATAMENTO ENDODONTICO BIRRADICULAR (Similarity: 100)
# RETRATAMENTO ENDODONTICO MULTIRADICULAR => RETRATAMENTO ENDODONTICO MULTIRRADICULAR (Similarity: 99)
# ULOTOMIA => ULOTOMIA (Similarity: 100)
# RESTAURACAO EM IONOMERO DE VIDRO - 4 FACES => RESTAURAÇÃO EM IONOMERO DE VIDRO 4 FACES (Similarity: 97)
# AJUSTE OCLUSAL POR DESGASTE SELETIVO => AJUSTE OCLUSAL POR DESGASTE SELETIVO (Similarity: 100)
# NUCLEO DE PREENCHIMENTO => NUCLEO DE PREENCHIMENTO (Similarity: 100)
# SEPULTAMENTO RADICULAR => SEPULTAMENTO RADICULAR (Similarity: 100)
# PROTESE PARCIAL REMOVIVEL COM GRAMPOS => PROTESE PARCIAL REMOVIVEL COM GRAMPOS (Similarity: 100)
# PROTESE TOTAL => PROTESE TOTAL (Similarity: 100)
# COROA PROVISORIA SEM PINO => COROA PROVISORIA SEM PINO (Similarity: 100)
# RETRATAMENTO ENDODONTICO UNIRADICULAR => RETRATAMENTO ENDODONTICO UNIRADICULAR (Similarity: 100)
# IMOBILIZACAO DENTARIA EM DENTES DECIDUOS => Imobilização dentária em dentes decíduos (Similarity: 82)
# INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL => Incisão e Drenagem extra-oral de abscesso, hematoma e/ou flegmão da
# região buco-maxilo-facial (Similarity: 98)
# DRENABCESINTRA => DRENABCESINTRA (Similarity: 100)
# REDUCAO SIMPLES DE LUXACAO DE ARTICULACAO TEMPORO- MANDIBULAR (ATM) => Redução simples de luxação de Articulação Temporo-Mandibular (ATM) (Similarity: 95)
# TRATAMENTO DE ABSCESSO PERIODONTAL AGUDO => Tratamento de abscesso periodontal agudo (Similarity: 100)
# TRATAMENTO DE PERICORONARITE => Tratamento de pericoronarite (Similarity: 100)
# CONSULTA ODONTOLOGICA INICIAL => CONSULTA ODONTOLOGICA INICIAL (Similarity: 100)
# DIAGNOSTICO ANATOMOPATOLOGICO EM CITOLOGIA ESFOLIATIVA NA REGIAO BUCO-MAXILO-FACIAL  => Diagnóstico anatomopatológico em citologia esfoliativa na região buco-maxilo-facial (Similarity: 98)
# DIAGNOSTICO ANATOMOPATOLOGICO EM PECA CIRURGICA NA REGIAO BUCO-MAXILO-FACIAL  => Diagnóstico anatomopatológico em peça cirúrgica na região buco-maxilo-facial (Similarity: 97)
# DIAGNOSTICO ANATOMOPATOLOGICO EM PUNCAO NA REGIAO BUCO-MAXILO-FACIAL => Diagnóstico anatomopatológico em punção na região buco-maxilo-facial (Similarity: 96)
# MODELOS ORTODONTICOS => Modelos ortodônticos (Similarity: 97)
# CLAREAMENTO DENTARIO CASEIRO => CLAREAMENTO DENTARIO CASEIRO (Similarity: 100)
# CLAREAMENTO DENTARIO DE CONSULTORIO => Clareamento dentário de consultório (Similarity: 97)
# CLAREAMENTO DENTARIO A LASER => Clareamento a laser (Similarity: 81)
# RESTAURACAO COM PINO => Restauração com Pino (Similarity: 95)
# APLICACAO TOPICA DE FLUOR => APLICACAO TOPICA DE FLUOR  (Similarity: 100)
# COROA DE ACETATO EM DENTE PERMANENTE => Coroa de acetato em dente permanente (Similarity: 100)
# COROA DE ACO EM DENTE DECIDUO => COROA DE ACO EM DENTE DECIDUO (Similarity: 100)
# COROA DE ACO EM DENTE PERMANENTE => Coroa de aço em dente permanente (Similarity: 98)
# COROA DE POLICARBONATO EM DENTE DECIDUO => COROA DE POLICARBONATO EM DENTE DECIDUO (Similarity: 100)
# COROA DE POLICARBONATO EM DENTE PERMANENTE => Coroa de policarbonato em dente permanente (Similarity: 100)
# REMOCAO DE NUCLEO INTRARRADICULAR => REMOCAO DE NUCLEO INTRARRADICULAR (Similarity: 100)
# TRATAMENTO DE PERFURACAO ENDODONTICA => Tratamento de perfuração endodôntica (Similarity: 96)
# TRATAMENTO ENDODONTICO DE DENTE COM RIZOGENESE INCOMPLETA => Tratamento endodôntico de dente com rizogenese incompleta (Similarity: 99)
# PRODUTOS: FIO DENTAL => Fio Dental Infantil (Similarity: 63)
# IMPLANTE OSSEO INTEGRADO => Implante ósseo integrado (Similarity: 98)
# BRIDOTOMIA => Bridotomia (Similarity: 100)
# CIRURGIA PARA EXOSTOSE MAXILAR => Cirurgia para exostose maxilar (Similarity: 100)
# EXERESE DE LIPOMA NA REGIAO BUCO-MAXILO-FACIAL => Exérese de lipoma na região buco-maxilo-facial (Similarity: 98)
# EXERESE OU EXCISAO DE CALCULO SALIVAR => Exerese ou excisão de calculo salivar (Similarity: 99)
# EXERESE OU EXCISAO DE MUCOCELE => EXERESE OU EXCISAO DE MUCOCELE (Similarity: 100)
# EXODONTIA DE PERMANENTE POR INDICACAO ORTODONTICA/PROTETICA => EXODONTIA DE PERMANENTE POR INDICAÇÃO ORTODONTICA/PROTETICA (Similarity: 98)
# EXODONTIA DE INCLUSOS / IMPACTADOS / SUPRANUMERARIO => EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS (Similarity: 86)
# TRACIONAMENTO CIRURGICO COM FINALIDADE ORTODONTICA => TRACIONAMENTO CIRURGICO COM FINALIDADE ORTODONTICA (Similarity: 100)
# TRATAMENTO CIRURGICO DE BRIDAS CONSTRITIVAS DA REGIAO BUCO-MAXILO-FACIAL => Tratamento cirúrgico de bridas constritivas da região buco-maxilo-facial (Similarity: 99)
# TRATAMENTO CIRURGICO DE FISTULAS BUCO-NASAIS => TRATAMENTO CIRURGICO DE FISTULAS BUCO SINUSAIS (Similarity: 96)
# TRATAMENTO CIRURGICO DE  HIPERPLASIAS DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL => Tratamento cirúrgico de hiperplasias de tecidos moles na região buco-maxilo-facial (Similarity: 99)
# TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL => TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL (Similarity: 100)
# CONSERTO EM PROTESE TOTAL / PARCIAL => CONSERTO EM PRÓTESE TOTAL (EXCLUSIVAMENTE EM (Similarity: 75)
# DIAGNOSTICO POR MEIO DE ENCERAMENTO => Diagnóstico por meio de enceramento (Similarity: 99)
# FACETA EM CERAMICA PURA => Faceta em cerâmica pura (Similarity: 98)
# FACETA EM CEROMERO => Faceta em cerômero (Similarity: 97)
# PLACA MIORELAXANTE => XANTELASMA (Similarity: 57)
# ORTESE REPOSICIONADORA (PLACA OCLUSAL REPOSICIONADORA) => Órtese reposicionadora (placa oclusal reposicionadora) (Similarity: 87)
# PLACA OCLUSAL RESILIENTE => Placa oclusal resiliente (Similarity: 100)
# PROTESE PARCIAL FIXA PROVISORIA => Prótese parcial fixa provisória (Similarity: 73)
# PROTESE ADESIVA EM CERAMICA => Prótese fixa adesiva indireta em metalo-cerâmica (Similarity: 68)
# PROTESE FIXA ADESIVA INDIRETA EM METALO PLASTICA => Prótese fixa adesiva indireta em metalo-plástica (Similarity: 98)
# PROTESE PARCIAL => RESSECCAO PARCIAL (Similarity: 75)
# DIAGNOSTICO E TRATAMENTO DE HALITOSE => Diagnóstico e tratamento de halitose (Similarity: 99)
# ACOMPANHAMENTO DE PROCEDIMENTIO CIRURGICO => RADIOSCOPIA PARA ACOMPANHAMENTO DE PROCEDIMENTO CIRURGICO (Similarity: 84)
# CONTROLE POS-OPERATORIO EM ODONTOLOGIA => Controle pós-operatório em odontologia (Similarity: 97)
# ORIENTACAO DE HIGIENE BUCAL => ORIENTACAO DE HIGIENHE BUCAL (Similarity: 98)
# REMOCAO DE ODONTOMA => Remoção de odontoma (Similarity: 94)
# SUTURA DE FERIDA EM REGIAO BUCO-MAXILO-FACIAL => Sutura de ferida em região buco-maxilo-facial (Similarity: 99)
# GUIA CIRURGICO PARA IMPLANTE => Guia cirúrgico para implante (Similarity: 98)
# ENXERTO OSSEO LIOFILIZADO => Enxerto com osso liofilizado (Similarity: 91)
# ENXERTO OSSEO AUTOGENO => Enxerto com osso autógeno do mento (Similarity: 73)
# LEVANTAMENTO DO SEIO MAXILAR COM OSSO AUTOGENO => Levantamento do seio maxilar com osso autógeno (Similarity: 99)
# LEVANTAMENTO DO SEIO MAXILAR COM OSSO HOMOLOGO => Levantamento do seio maxilar com osso homólogo (Similarity: 99)
# RESTAURAÇAO EM DENTE DECIDUO => RESTAURAÇÃO EM DENTE DECÍDUO (Similarity: 96)
# DESSENSIBILIZACAO DENTARIA => Dessensibilização dentária (Similarity: 94)
# RESTAURACAO TEMPORARIA / TRATAMENTO EXPECTANTE => Restauração temporária / tratamento expectante (Similarity: 96)
# TESTE DE PH SALIVAR => Teste de Ph salivar (Similarity: 100)
# CLAREAMENTO DE DENTE DESVITALIZADO => Clareamento de dente desvitalizado (Similarity: 100)
# ADEQUACAO DE MEIO BUCAL COM IONOMERO DE VIDRO) => ADEQUAÇÃO DE MEIO BUCAL COM IONÔMERO DE VIDRO (BOCA COMPLETA) (Similarity: 85)
# ESTABILIZACAO DE PACIENTE POR MEIO DE CONTENCAO FISICA E/OU MECANICA => Estabilização de paciente por meio de contenção física e/ou mecânica (Similarity: 95)
# AMPUTACAO RADICULAR COM OBTURACAO RETROGRADA => Amputação radicular com obturação retrógrada (Similarity: 94)
# AMPUTACAO RADICULAR SEM OBTURACAO RETROGRADA => AMPUTAÇAO RADICULAR SEM OBTURAÇAO RETROGRADA (Similarity: 98)
# COROA TOTAL ACRILICA PRENSADA => Coroa total acrílica prensada (Similarity: 98)
# REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL => REEMBASAMENTO DE PRÓTESE TOTAL OU PARCIAL - MEDIATO (em consultório) (Similarity: 83)
# RESTAURACAO EM CEROMERO - INLAY => RESTAURACAO EM CEROMERO ONLAY (Similarity: 97)
# RESTAURACAO EM CEROMERO - ONLAY => RESTAURACAO EM CEROMERO ONLAY (Similarity: 100)
# RESTAURACAO EM CERAMICA - INLAY => Restauração em cerâmica pura - inlay (Similarity: 87)
# RESTAURACAO EM CERAMICA - ONLAY => Restauração em cerâmica pura - onlay (Similarity: 87)
# COROA PROVISORIA => COROA PROVISÓRIA S/PINO (Similarity: 79)
# OVERDENTURE BARRA CLIPE OU ORING SOBRE DOIS IMPLANTES => Overdenture barra clipe ou o'ring sobre dois implantes (Similarity: 92)
# OVERDENTURE BARRA CLIPE OU ORING SOBRE TRES IMPLANTES => Overdenture barra clipe ou o'ring sobre três implantes (Similarity: 91)
# OVERDENTURE BARRA CLIPE OU ORING SOBRE QUATRO OU MAIS IMPLANTES => Overdenture barra clipe ou o'ring sobre quatro ou mais implantes (Similarity: 93)
# PRODUTOS: KIT ORTODONTICO => Kit ortodôntico - pasta (Similarity: 77)
# ATIVIDADE EDUCATIVA EM SAUDE BUCAL => ATIVIDADE EDUCATIVA EM SAUDE BUCAL (Similarity: 100)
# CONTROLE DE BIOFILME => CONTROLE DE BIOFILME (PLAC  (Similarity: 89)
# TRATAMENTO DE MANUTENCAO PARA PERIODONTITE LEVE => Tratamento de pericoronarite (Similarity: 64)
# CONTROLE DE CARIE INCIPIENTE => CONTROLE DE CÁRIE INCIPIENTE (Similarity: 80)
# RESTAURACAO ATRAUMATICA EM DENTE PERMANENTE => RESTAURAÇÃO ATRAUMÁTICA EM DENTE PERMANENTE (Similarity: 96)
# PREPARO PARA NUCLEO INTRARRADICULAR => PREPARO PARA NUCLEO INTRARRADICULAR (Similarity: 100)
# CIRURGIA ODONTOLOGICA COM APLICACAO DE ALOENXERTOS => CIRURGIA ODONTOLÓGICA COM APLICAÇÃO DE ALOENXERTOS (Similarity: 97)
# PUNCAO ASPIRATIVA NA REGIAO BUCO-MAXILO-FACIAL => PUNÇÃO ASPIRATIVA NA REGIAO BUCO-MAXILO-FACIAL (Similarity: 98)
# RECONSTRUCAO DE DENTE COM PINO => RECONSTRUCAO DE PENIS COM ENXERTO (Similarity: 83)
# CIRURGIA ODONTOLOGICA A RETALHO => Cirurgia odontológica a retalho (Similarity: 98)
# IMPLANTE ORTODONTICO => Implante ortodôntico (Similarity: 97)
# IMPLANTE ZIGOMATICO => Implante Zigomático (Similarity: 97)
# LEVANTAMENTO DO SEIO MAXILAR COM OSSO LIOFILIZADO => Levantamento do seio maxilar com osso liofilizado (Similarity: 100)
# ARCO LINGUAL => ARCO LINGUAL (Similarity: 100)
# PISTAS DIRETAS DE PLANAS SUPERIOR E/OU INFERIOR => PISTAS DIRETAS DE PLANAS - SUPERIOR OU INFERIOR (Similarity: 98)
# RESTAURACAO EM RESINA INDIRETA - INLAY => RESTAURAÇÃO EM RESINA (INDIRETA) - INLAY (Similarity: 97)
# COROA TOTAL EM CERAMICA PURA => COROA TOTAL EM CERÂMICA PURA (Similarity: 98)
# GUIA CIRURGICO PARA PROTESE TOTAL IMEDIATA => GUIA CIRURGICO PARA PRÓTESE TOTAL IMEDIATA (Similarity: 99)
# RESTAURACAO EM RESINA INDIRETA - ONLAY => RESTAURAÇÃO EM RESINA (INDIRETA) - ONLAY (Similarity: 97)
# REMOCAO DE TRABALHOS PROTETICOS => REMOÇÃO DE TRABALHO PROTÉTICO (Similarity: 91)
# MARSUPIALIZACAO DE CISTOS ODONTOLOGICOS => MARSUPIALIZAÇÃO DE CISTOS ODONTOLÓGICOS (Similarity: 96)
# CURETAGEM APICAL => CURETAGEM APICAL (Similarity: 100)
# DIAGNOSTICO E PLANEJAMENTO PARA TRATAMENTO ODONTOLOGICO => DIAGNÓSTICO E PLANEJAMENTO PARA TRATAMENTO ODONTOLÓGICO (Similarity: 98)
# DIAGNOSTICO POR MEIO DE descricaoS LABORATORIAIS => DIAGNÓSTICO POR MEIO DE PROCEDIMENTOS LABORATORIAIS (Similarity: 73)
# APLICACAO DE LASER TERAPEUTICO => APLICAÇÃO DE LASER TERAPÊUTICO (Similarity: 95)
# PROVISORIO PARA FACETA => PROVISÓRIO PARA FACETA (Similarity: 98)
# PROVISORIO PARA INLAY/ONLAY => PROVISÓRIO PARA INLAY/ONLAY (Similarity: 98)
# CONSULTA ODONTOLOGICA EM ESPECIALISTA => CONSULTA DE ESPECIALISTA EM ESTOMATOLOGIA (Similarity: 85)
# TRATAMENTO DE MANUTENCAO PARA PERIODONTITE MODERADA => Pacote - Tratamento tipo I - manutenção mensal (Similarity: 66)
# CONTROLE DE HEMORRAGIA COM APLICACAO DE AGENTE => Controle de hemorragia com aplicação de agente hemostático em região buco-maxilo-facial (Similarity: 70)
# CONTROLE DE HEMORRAGIA SEM APLICACAO DE AGENTE => Controle de hemorragia sem aplicação de agente hemostático em região buco-maxilo-facial (Similarity: 70)
# TRATAMENTO DE MANUTENCAO PARA PERIODONTITE GRAVE => Tratamento de abscesso periodontal agudo (Similarity: 64)
# TRATAMENTO DE PERIOD. DE MANUT. P/ PERIODONTITE LEVE 6 EM 6 MESES => QUIMIOTERAPIA SISTEMICA POR PERIODOS DE 7 DIAS DE TRATAMENTO (Similarity: 59)
# PLANEJAMENTO DE TRATAMENTO ORTODONTICO => DIAGNOSTICO E PLANEJAMENTO PARA TRATAMENTO ORTODONTICO (Similarity: 83)
# TRATAMENTO DA ARTICULACAO TEMPOROMANDIBULAR ATM => Tratamento conservador de luxação da articulação têmporo-mandibular - ATM (Similarity: 71)
# EXODONTIA SIMPLES DE PERMANENTE => Exodontia simples de permanente (Similarity: 100)
# EMERGENCIA ODONTOLOGICA => CONSULTA ODONTOLOGICA (Similarity: 68)
# TOMOGRAFIA => TONOGRAFIA (Similarity: 90)
# PRODUTOS: CLOREXIDINA => Kit Clorexidina (Similarity: 74)
# RADIOGRAFIA PANORAMICA => Radiografia Periapical (Similarity: 82)
# MOLDAGEM ORTODONTICA => Modelos ortodônticos (Similarity: 72)
# OSTEOPLASTIA => URETEROPLASTIA (Similarity: 77)
# APARELHO DE PROTRACAO MANDIBULAR -  APM => Aparelho de protração mandibular -  APM (Similarity: 97)
# ADESAO AO PLANO ORTODONTICO COMUM => ADESÃO AO PLANO ORTODÔNTICO (Similarity: 86)
# APARELHO ORTODONTICO FIXO - RESINA => Aparelho ortodôntico fixo Resina (Similarity: 98)
# APARELHO ORTODONTICO FIXO - PORCELANA => Aparelho ortodôntico fixo Porcelana (Similarity: 99)
# APARELHO FIXO AUTO-LIGADO => Braquete Aparelho Auto Ligado (Similarity: 78)
# APARELHO ORTODONTICO FIXO - SAFIRA => Aparelho ortodôntico fixo Safira (Similarity: 98)
# APARELHO ORTODONTICO FIXO - METALICO => Aparelho ortodôntico fixo metálico (Similarity: 97)
# APARELHO ORTODONTICO MOVEL => APARELHO ORTODÔNTICO FIXO (Similarity: 84)
# APARELHO ORTODONTICO MOVEL  => APARELHO ORTODÔNTICO FIXO (Similarity: 84)
# DENTE UNITARIO EM APARELHO ORTODÔNTICO => Dente unitário para aparelho ortodôntico (Similarity: 88)
# ALETAS GOMES => Aletas Gomes (Similarity: 100)
# APARELHO DE THUROW => Aparelho de Thurow (Similarity: 100)
# APARELHO EXTRA-BUCAL => Aparelho extra-bucal (Similarity: 100)
# APARELHO ORTODONTICO - MASCARA FACIAL => Aparelho Ortopédico (Mascara Facial) (Similarity: 94)
# APARELHO ORTODONTICO - SPLINT => Porta Aparelho Ortodontico (Similarity: 87)
# APARELHO PROTETOR BUCAL => Aparelho protetor bucal (Similarity: 100)
# PROVISORIO PARA RESTAURACAO METALICA FUNDIDA => Provisório para Restauração metálica fundida (Similarity: 95)
# INTERMEDIARIO PROTETICO (PARA IMPLANTES) => Intermediário protético (para implantes) (Similarity: 97)
# MANUTENCAO DE PROTESE SOBRE IMPLANTES => PCT - Manutenção de prótese sobre implantes C/HM (Similarity: 85)
# PROTOCOLO BRANEMARK PROVISORIO PARA 4 IMPLANTES => Protocolo Branemark provisório para 4 implantes (Similarity: 99)
# REPOSICAO DE BRAQUETE METALICO => Braquete Metálico (Similarity: 70)
# REPOSICAO DE BRAQUETE PORCELANA => Braquete Porcelana (Similarity: 73)
# REPOSICAO DE BRAQUETE RESINA => Braquete Resina (Similarity: 70)
# PRODUTOS: CERA ORTODONTICA => Cera Ortodontica (Similarity: 78)
# PRODUTOS: CREME DENTAL => Creme Dental Paradontax (Similarity: 77)
# PRODUTOS: ESCOVA DENTAL => PROVAS DE ESFORCO (Similarity: 62)
# PRODUTOS: GEL BUCAL => Gel Bucal Sem Fluor (Similarity: 59)
# MANUTENCAO ORTODONTICA - APARELHO AUTO-LIGADO => Manutenção de aparelho ortodôntico - Auto Ligado 180 (Similarity: 87)
# MANUTENCAO ORTODONTICA - APARELHO METALICO => Manutenção de aparelho ortodôntico - Metálico 80 (Similarity: 85)
# MANUTENCAO ORTODONTICA - APARELHO ORTOPEDICO => MANUTENÇAO DE APARELHO ORTODONTICO - APARELHO ORTOPEDICO (Similarity: 84)
# COROA TOTAL METALO PLASTICA – RESINA ACRILICA => Coroa total metalo plástica - resina acrílica (Similarity: 98)
# IMOBILIZACAO DENTARIA EM DENTES PERMANENTES => IMOBILIZACAO DENTARIA EM DENTES PERMANENTES (Similarity: 100)
# PROTESE PROTOCOLO AJUSTE => PROTOCOLO DE FOTOS (Similarity: 71)
# RESTAURACAO PROVISORIA => PCT - Restauração Provisória C/HM (Similarity: 76)
# AVALIACAO ODONTOLOGICA ORTODONTICO => Avaliação Odontológica (Similarity: 72)
# AVALIACAO ODONTOLOGICA CIRURGIA => Avaliação Odontológica (Similarity: 76)
# AVALIACAO ODONTOLOGICA ENDODONTIA => Avaliação Odontológica (Similarity: 73)
# AVALIACAO ODONTOLOGICA PROTESE => Avaliação Odontológica (Similarity: 78)
# AVALIACAO ODONTOLOGICA IMPLANTE => Avaliação Odontológica (Similarity: 76)
# AVALIACAO ODONTOLOGICA ESTETICA FACIAL => CONSULTA ODONTOLOGICA INICIAL (Similarity: 69)
# AVALIACAO ODONTOLOGICA PERIODONTIA => Avaliação Odontológica (Similarity: 72)
# AVALIACAO ODONTOLOGICA KIDS => Avaliação Odontológica (Similarity: 83)
# PROTESE FIXA ADESIVA EM CEROMERO LIVRE DE METAL (METAL FREE) => Prótese fixa adesiva em cerômero livre de metal (metal free) (Similarity: 98)
# MANUTENCAO ORTODONTICA - APARELHO RESINA => Manutenção de aparelho ortodôntico - Resina 80 (Similarity: 86)
# MANUTENCAO ORTODONTICA - APARELHO PORCELANA => Manutenção de aparelho ortodôntico - Porcelana 150 (Similarity: 86)
# MANUTENCAO ORTODONTICA KIDS => MANUTENÇÃO ORTODÔNTICA KIDS | R$ 85,00	 (Similarity: 81)
# MANUTENCAO ORTODONTICA GRATUITA => MANUTENCAO PERIODONTAL KIT (Similarity: 74)
# MANUTENCAO ORTODONTICA PROMOCIONAL (PRIMEIRA) => PRIMEIRA MANUTENÇÃO ORTODÔNTICA PROMOCIONAL (Similarity: 96)
# AVALIACAO ODONTOLOGICA => Avaliação Odontológica (Similarity: 93)
# DIAGNOSTICO E PLANEJAMENTO ORTODONTICO => DIAGNÓSTICO E PLANEJAMENTO ODONTOLÓGICO (Similarity: 91)
# BIOPSIA DE BOCABIOPSIA DE LABIOBIOPSIA DE LINGUABIOPSIA DE MANDIBULABIOPSIA DE MAXILABIOPSIA DE GLANDULA SALIVAR => LARINGOSCOPIA DIRETA - PARA DIAGNOSTICO, COLHEITA DE MATERIAL E/OU BIOPSIA (Similarity: 48)

# %%
mapped_products
# Out:
# {'CONSULTA ODONTOLOGICA': ('CONSULTA ODONTOLOGICA', 100),
#  'URGENCIA ODONTOLOGICA': ('CONSULTA ODONTOLOGICA - URGENCIA', 82),
#  'PULPOTOMIA': ('Pulpotomia', 100),
#  'RECIMENTACAO DE TRABALHOS PROTETICOS': ('RECIMENTAÇÃO DE TRABALHOS PROTÉTICOS',
#   96),
#  'TRATAMENTO DE ALVEOLITE': ('Tratamento de Alveolite', 100),
#  'COLAGEM DE FRAGMENTOS DENTARIOS': ('Colagem de fragmentos dentários', 98),
#  'CONTROLE DE HEMORRAGIA': ('HEMACIAS CONTAGEM DE', 71),
#  'INCISAO E DRENAGEM EXTRA ORAL DE ABSCESSO, HEMATOMA E/OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL': ('Incisão e Drenagem extra-oral de abscesso, hematoma e/ou flegmão da\nregião buco-maxilo-facial',
#   98),
#  'INCISAO E DRENAGEM INTRA ORAL DE ABSCESSO, HEMATOMA E/OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL': ('Incisão e Drenagem intra-oral de abscesso, hematoma e/ou flegmão da região buco-maxilo-facial',
#   98),
#  'REIMPLANTE DENTARIO COM CONTENCAO': ('REIMPLANTE DENTARIO COM CONTENÇAO',
#   98),
#  'CURATIVO DE DEMORA': ('EMER-CURATIVO', 77),
#  'APLICACAO DE SELANTE DE FOSSULAS E FISSURAS': ('APLICACAO DE SELANTE DE FOSSULAS E FISSURAS',
#   100),
#  'APLICACAO DE CARIOSTATICO': ('Aplicação de Cariostático', 94),
#  'ADEQUACAO DO MEIO BUCAL': ('Adequação do meio bucal', 95),
#  'REMINERALIZACAO': ('REMINERALIZAÇAO', 97),
#  'TESTE DE FLUXO SALIVAR': ('Teste de fluxo salivar', 100),
#  'CONDICIONAMENTO EM ODONTOLOGIA': ('Condicionamento em Odontologia ', 100),
#  'COROA DE ACETATO EM DENTE DECIDUO': ('Coroa de acetato em dente decíduo',
#   98),
#  'EXODONTIA DE DECIDUOS': ('EXODONTIA DE DECIDUOS', 100),
#  'TRATAMENTO ENDODONTICO EM DENTE DECIDUO': ('TRATAMENTO ENDODONTICO EM DENTE DECIDUO',
#   100),
#  'EXODONTIA DE PERMANENTE': ('EXODONTIA DE DENTE PERMANENTE', 88),
#  'EXODONTIA DE RAIZ RESIDUAL': ('Exodontia de Raiz Residual', 100),
#  'EXODONTIA A RETALHO': ('Exodontia a Retalho', 100),
#  'ODONTO-SECCAO': ('Odonto-secção', 92),
#  'ALVEOLOPLASTIA': ('Alveoloplastia ', 100),
#  'FRENULECTOMIA': ('Ulectomia  ', 82),
#  'EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS / SUPRANUMERARIO': ('EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS',
#   83),
#  'EXODONTIA DE INCLUSOS / IMPACTADOS': ('EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS',
#   93),
#  'AUMENTO DE COROA CLINICA': ('AUMENTO DE COROA CLINICA', 100),
#  'ULECTOMIA': ('Ulectomia  ', 100),
#  'APICETOMIA UNIRRADICULARES SEM OBTURACAO RETROGRADA': ('APICETOMIA UNIRRADICULARES SEM OBTURAÇAO RETROGRADA',
#   99),
#  'APICETOMIA BIRRADICULARES SEM OBTURACAO RETROGRADA': ('APICETOMIA BIRRADICULARES SEM OBTURAÇAO RETROGRADA',
#   99),
#  'APICETOMIA MULTIRRADICULARES SEM OBTURACAO RETROGRADA': ('APICETOMIA MULTIRRADICULARES SEM OBTURAÇAO RETROGRADA',
#   99),
#  'APICETOMIA UNIRRADICULARES COM OBTURACAO RETROGRADA': ('APICETOMIA UNIRRADICULARES COM OBTURAÇAO RETROGRADA',
#   99),
#  'APICETOMIA BIRRADICULARES COM OBTURACAO RETROGRADA': ('APICETOMIA BIRRADICULARES COM OBTURAÇAO RETROGADA',
#   98),
#  'APICETOMIA MULTIRRADICULARES COM OBTURACAO RETROGRADA': ('APICETOMIA MULTIRRADICULARES COM OBTURAÇAO RETROGRADA',
#   99),
#  'BIOPSIA': ('BIOPSIA', 100),
#  'RESTAURACAO DE AMALGAMA - 1 FACE': ('RESTAURACAO DE AMALGAMA 1 FACE', 100),
#  'RESTAURACAO DE AMALGAMA - 2 FACES': ('RESTAURACAO DE AMALGAMA 2 FACES', 100),
#  'RESTAURACAO DE AMALGAMA - 3 FACES': ('RESTAURACAO DE AMALGAMA 3 FACES ',
#   100),
#  'RESTAURACAO DE AMALGAMA - 4 FACES': ('RESTAURACAO DE AMALGAMA 4 FACES', 100),
#  'RESTAURACAO EM RESINA 1 FACE': ('RESTAURACAO EM RESINA 1 FACE ', 100),
#  'RESTAURACAO EM RESINA 2 FACES': ('RESTAURACAO EM RESINA 2 FACES', 100),
#  'RESTAURACAO EM RESINA 3 FACES': ('RESTAURACAO EM RESINA 3 FACES ', 100),
#  'RESTAURACAO EM RESINA 4 FACES': ('RESTAURACAO EM RESINA 4 FACES ', 100),
#  'RESTAURACAO EM IONOMERO DE VIDRO - 1 FACE': ('RETAURAÇAO EM IONOMERO DE VIDRO 1 FACE',
#   97),
#  'RESTAURACAO EM IONOMERO DE VIDRO - 2 FACES': ('Restauração em ionômero de vidro 2 faces',
#   96),
#  'RESTAURACAO EM IONOMERO DE VIDRO - 3 FACES': ('Restauração em ionômero de vidro 3 faces',
#   96),
#  'CIRURGIA PARA TORUS MANDIBULAR – UNILATERAL': ('Cirurgia para torus mandibular - unilateral',
#   100),
#  'CIRURGIA PARA TORUS MANDIBULAR – BILATERAL': ('Cirurgia para torus mandibular - bilateral',
#   100),
#  'CIRURGIA PARA TORUS PALATINO': ('Cirurgia para torus palatino', 100),
#  'BRIDECTOMIA': ('Bridectomia', 100),
#  'EXERESE OU EXCISAO DE RANULA': ('Exerese ou excisão de rânula', 96),
#  'EXERESE OU EXCISAO DE CISTOS ODONTOLOGICOS': ('EXERESE OU EXCISAO DE CISTO ODONTOLOGICO',
#   98),
#  'COLETA DE RASPADO EM LESOES OU SITIOS ESPECIFICOS DA REGIAO BUCO-MAXILO-FACIAL': ('Coleta de raspado em lesões ou sítios específicos da região buco-maxilo-facial',
#   97),
#  'REDUCAO SIMPLES DE LUXACAO DA ATM': ('REDUCAO DE LUXACAO DA ATM', 86),
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU BUCO SINUSAIS': ('TRATAMENTO CIRURGICO DE FISTULAS BUCO NASAIS OU SINUSAIS',
#   96),
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL': ('TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#   91),
#  'TRATAMENTO CIRURGICO DE TUMORES BENIGNOS E HIPERPLASIA DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL': ('Tratamento cirúrgico dos tumores benignos de tecidos moles na região\nbuco-maxilo-facial',
#   90),
#  'TRATAMENTO CIRURGICO PARA TUMORES ODONTOGENICOS BENIGNOS - SEM RECONSTRUCAO': ('Tratamento cirúrgico para tumores benignos odontogênicos - sem reconstrução',
#   97),
#  'COROA PROVISORIA COM PINO': ('COROA PROVISORIA COM PINO', 100),
#  'PINO PRE FABRICADO': ('Pino Pré Fabricado', 97),
#  'COROA METALO CERAMICA': ('Coroa metalo-cerâmica', 98),
#  'COROA TOTAL METALICA': ('COROA TOTAL METALICA', 100),
#  'COROA TOTAL EM CEROMERO': ('COROA TOTAL EM CEROMERO', 100),
#  'NUCLEO METALICO FUNDIDO': ('Núcleo metálico fundido', 95),
#  'RESTAURACAO METALICA FUNDIDA': ('Restauração metálica fundida', 94),
#  'PROFILAXIA E POLIMENTO CORONARIO': ('PROFILAXIA POLIMENTO CORONARIO', 97),
#  'RADIOGRAFIA PERIAPICAL': ('Radiografia Periapical', 100),
#  'RASPAGEM SUPRA-GENGIVAL PARA TRATAMENTO DA GENGIVITE': ('TRATAMENTO DE GENGIVITE NECROSANTE AGUDA GNA',
#   67),
#  'TRATAMENTO ENDODONTICO BIRRADICULAR': ('TRATAMENTO ENDODONTICO BIRRADICULAR',
#   100),
#  'TRATAMENTO ENDODONTICO MULTIRADICULAR': ('TRATAMENTO ENDODONTICO MULTIRADICULAR',
#   100),
#  'TRATAMENTO ENDODONTICO UNIRADICULAR': ('TRATAMENTO ENDODONTICO UNIRRADICULAR',
#   99),
#  'FOTOGRAFIA': ('FOTOGRAFIA', 100),
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE HERPETICA': ('DIAGNOSTICO E TRATAMENTO DE ESTOMATITE HERPETICA',
#   100),
#  'DIAGNOSTICO E TRATAMENTO DE ESTOMATITE POR CANDIDOSE': ('Diagnóstico e tratamento de estomatite por candidose',
#   99),
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM MATERIAL DE BIOPSIA NA REGIAO BUCO-MAXILO-FACIAL ': ('Diagnóstico anatomopatológico em material de biópsia na região buco-maxilo-facial',
#   97),
#  'DIAGNOSTICO E TRATAMENTO DE XEROSTOMIA ': ('DIAGNOSTICO E TRATAMENTO DE XEROSTOMIA',
#   100),
#  'DOCUMENTACAO ORTODONTICA': ('DOCUMENTACAO ORTODONTICA', 100),
#  'RASPAGEM SUB-GENGIVAL': ('RASPAGEM SUB GENGIVAL', 100),
#  'IMOBILIZACAO EM DENTES PERMANENTES': ('IMOBILIZACAO DENTARIA EM DENTES PERMANENTES',
#   88),
#  'GENGIVECTOMIA': ('GENGIVECTOMIA', 100),
#  'TUNELIZACAO': ('TUNELIZACAO', 100),
#  'GENGIVOPLASTIA': ('GENGIVOPLASTIA', 100),
#  'ENXERTO CONJUNTIVO SUBEPITELIAL': ('ENXERTO CONJUNTIVO SUBEPITELIAL', 100),
#  'CIRURGIA PERIODONTAL A RETALHO': ('CIRURGIA PERIODONTAL A RETALHO', 100),
#  'CUNHA PROXIMAL': ('CUNHA PROXIMAL', 100),
#  'ENXERTO GENGIVAL LIVRE': ('ENXERTO GENGIVAL LIVRE', 100),
#  'ENXERTO PEDICULADO': ('ENXERTO PEDICULADO', 100),
#  'MANUTENCAO ORTODONTICA GENERICA': ('MANUTENCAO APARELHO ORTODONTICO FIXO',
#   72),
#  'CONTENCAO ORTODONTICA': ('Cera Ortodontica', 81),
#  'FACETA DIRETA EM RESINA FOTOPOLIMERIZAVEL': ('FACETA DIRETA EM RESINA FOTOPOLIMERIZAVEL',
#   100),
#  'RETRATAMENTO ENDODONTICO BIRRADICULAR': ('RETRATAMENTO ENDODONTICO BIRRADICULAR',
#   100),
#  'RETRATAMENTO ENDODONTICO MULTIRADICULAR': ('RETRATAMENTO ENDODONTICO MULTIRRADICULAR',
#   99),
#  'ULOTOMIA': ('ULOTOMIA', 100),
#  'RESTAURACAO EM IONOMERO DE VIDRO - 4 FACES': ('RESTAURAÇÃO EM IONOMERO DE VIDRO 4 FACES',
#   97),
#  'AJUSTE OCLUSAL POR DESGASTE SELETIVO': ('AJUSTE OCLUSAL POR DESGASTE SELETIVO',
#   100),
#  'NUCLEO DE PREENCHIMENTO': ('NUCLEO DE PREENCHIMENTO', 100),
#  'SEPULTAMENTO RADICULAR': ('SEPULTAMENTO RADICULAR', 100),
#  'PROTESE PARCIAL REMOVIVEL COM GRAMPOS': ('PROTESE PARCIAL REMOVIVEL COM GRAMPOS',
#   100),
#  'PROTESE TOTAL': ('PROTESE TOTAL', 100),
#  'COROA PROVISORIA SEM PINO': ('COROA PROVISORIA SEM PINO', 100),
#  'RETRATAMENTO ENDODONTICO UNIRADICULAR': ('RETRATAMENTO ENDODONTICO UNIRADICULAR',
#   100),
#  'IMOBILIZACAO DENTARIA EM DENTES DECIDUOS': ('Imobilização dentária em dentes decíduos',
#   82),
#  'INCISAO E DRENAGEM EXTRA-ORAL DE ABSCESSO, HEMATOMA E/ OU FLEGMAO DA REGIAO BUCO-MAXILO-FACIAL': ('Incisão e Drenagem extra-oral de abscesso, hematoma e/ou flegmão da\nregião buco-maxilo-facial',
#   98),
#  'DRENABCESINTRA': ('DRENABCESINTRA', 100),
#  'REDUCAO SIMPLES DE LUXACAO DE ARTICULACAO TEMPORO- MANDIBULAR (ATM)': ('Redução simples de luxação de Articulação Temporo-Mandibular (ATM)',
#   95),
#  'TRATAMENTO DE ABSCESSO PERIODONTAL AGUDO': ('Tratamento de abscesso periodontal agudo',
#   100),
#  'TRATAMENTO DE PERICORONARITE': ('Tratamento de pericoronarite', 100),
#  'CONSULTA ODONTOLOGICA INICIAL': ('CONSULTA ODONTOLOGICA INICIAL', 100),
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM CITOLOGIA ESFOLIATIVA NA REGIAO BUCO-MAXILO-FACIAL ': ('Diagnóstico anatomopatológico em citologia esfoliativa na região buco-maxilo-facial',
#   98),
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PECA CIRURGICA NA REGIAO BUCO-MAXILO-FACIAL ': ('Diagnóstico anatomopatológico em peça cirúrgica na região buco-maxilo-facial',
#   97),
#  'DIAGNOSTICO ANATOMOPATOLOGICO EM PUNCAO NA REGIAO BUCO-MAXILO-FACIAL': ('Diagnóstico anatomopatológico em punção na região buco-maxilo-facial',
#   96),
#  'MODELOS ORTODONTICOS': ('Modelos ortodônticos', 97),
#  'CLAREAMENTO DENTARIO CASEIRO': ('CLAREAMENTO DENTARIO CASEIRO', 100),
#  'CLAREAMENTO DENTARIO DE CONSULTORIO': ('Clareamento dentário de consultório',
#   97),
#  'CLAREAMENTO DENTARIO A LASER': ('Clareamento a laser', 81),
#  'RESTAURACAO COM PINO': ('Restauração com Pino', 95),
#  'APLICACAO TOPICA DE FLUOR': ('APLICACAO TOPICA DE FLUOR ', 100),
#  'COROA DE ACETATO EM DENTE PERMANENTE': ('Coroa de acetato em dente permanente',
#   100),
#  'COROA DE ACO EM DENTE DECIDUO': ('COROA DE ACO EM DENTE DECIDUO', 100),
#  'COROA DE ACO EM DENTE PERMANENTE': ('Coroa de aço em dente permanente', 98),
#  'COROA DE POLICARBONATO EM DENTE DECIDUO': ('COROA DE POLICARBONATO EM DENTE DECIDUO',
#   100),
#  'COROA DE POLICARBONATO EM DENTE PERMANENTE': ('Coroa de policarbonato em dente permanente',
#   100),
#  'REMOCAO DE NUCLEO INTRARRADICULAR': ('REMOCAO DE NUCLEO INTRARRADICULAR',
#   100),
#  'TRATAMENTO DE PERFURACAO ENDODONTICA': ('Tratamento de perfuração endodôntica',
#   96),
#  'TRATAMENTO ENDODONTICO DE DENTE COM RIZOGENESE INCOMPLETA': ('Tratamento endodôntico de dente com rizogenese incompleta',
#   99),
#  'PRODUTOS: FIO DENTAL': ('Fio Dental Infantil', 63),
#  'IMPLANTE OSSEO INTEGRADO': ('Implante ósseo integrado', 98),
#  'BRIDOTOMIA': ('Bridotomia', 100),
#  'CIRURGIA PARA EXOSTOSE MAXILAR': ('Cirurgia para exostose maxilar', 100),
#  'EXERESE DE LIPOMA NA REGIAO BUCO-MAXILO-FACIAL': ('Exérese de lipoma na região buco-maxilo-facial',
#   98),
#  'EXERESE OU EXCISAO DE CALCULO SALIVAR': ('Exerese ou excisão de calculo salivar',
#   99),
#  'EXERESE OU EXCISAO DE MUCOCELE': ('EXERESE OU EXCISAO DE MUCOCELE', 100),
#  'EXODONTIA DE PERMANENTE POR INDICACAO ORTODONTICA/PROTETICA': ('EXODONTIA DE PERMANENTE POR INDICAÇÃO ORTODONTICA/PROTETICA',
#   98),
#  'EXODONTIA DE INCLUSOS / IMPACTADOS / SUPRANUMERARIO': ('EXODONTIA DE SEMI-INCLUSOS / IMPACTADOS',
#   86),
#  'TRACIONAMENTO CIRURGICO COM FINALIDADE ORTODONTICA': ('TRACIONAMENTO CIRURGICO COM FINALIDADE ORTODONTICA',
#   100),
#  'TRATAMENTO CIRURGICO DE BRIDAS CONSTRITIVAS DA REGIAO BUCO-MAXILO-FACIAL': ('Tratamento cirúrgico de bridas constritivas da região buco-maxilo-facial',
#   99),
#  'TRATAMENTO CIRURGICO DE FISTULAS BUCO-NASAIS': ('TRATAMENTO CIRURGICO DE FISTULAS BUCO SINUSAIS',
#   96),
#  'TRATAMENTO CIRURGICO DE  HIPERPLASIAS DE TECIDOS MOLES NA REGIAO BUCO-MAXILO-FACIAL': ('Tratamento cirúrgico de hiperplasias de tecidos moles na região buco-maxilo-facial',
#   99),
#  'TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL': ('TRATAMENTO CIRURGICO DE HIPERPLASIAS DE TECIDOS OSSEOS/CARTILAGINOSOS NA REGIAO BUCO-MAXILO-FACIAL',
#   100),
#  'CONSERTO EM PROTESE TOTAL / PARCIAL': ('CONSERTO EM PRÓTESE TOTAL (EXCLUSIVAMENTE EM',
#   75),
#  'DIAGNOSTICO POR MEIO DE ENCERAMENTO': ('Diagnóstico por meio de enceramento',
#   99),
#  'FACETA EM CERAMICA PURA': ('Faceta em cerâmica pura', 98),
#  'FACETA EM CEROMERO': ('Faceta em cerômero', 97),
#  'PLACA MIORELAXANTE': ('XANTELASMA', 57),
#  'ORTESE REPOSICIONADORA (PLACA OCLUSAL REPOSICIONADORA)': ('Órtese reposicionadora (placa oclusal reposicionadora)',
#   87),
#  'PLACA OCLUSAL RESILIENTE': ('Placa oclusal resiliente', 100),
#  'PROTESE PARCIAL FIXA PROVISORIA': ('Prótese parcial fixa provisória', 73),
#  'PROTESE ADESIVA EM CERAMICA': ('Prótese fixa adesiva indireta em metalo-cerâmica',
#   68),
#  'PROTESE FIXA ADESIVA INDIRETA EM METALO PLASTICA': ('Prótese fixa adesiva indireta em metalo-plástica',
#   98),
#  'PROTESE PARCIAL': ('RESSECCAO PARCIAL', 75),
#  'DIAGNOSTICO E TRATAMENTO DE HALITOSE': ('Diagnóstico e tratamento de halitose',
#   99),
#  'ACOMPANHAMENTO DE PROCEDIMENTIO CIRURGICO': ('RADIOSCOPIA PARA ACOMPANHAMENTO DE PROCEDIMENTO CIRURGICO',
#   84),
#  'CONTROLE POS-OPERATORIO EM ODONTOLOGIA': ('Controle pós-operatório em odontologia',
#   97),
#  'ORIENTACAO DE HIGIENE BUCAL': ('ORIENTACAO DE HIGIENHE BUCAL', 98),
#  'REMOCAO DE ODONTOMA': ('Remoção de odontoma', 94),
#  'SUTURA DE FERIDA EM REGIAO BUCO-MAXILO-FACIAL': ('Sutura de ferida em região buco-maxilo-facial',
#   99),
#  'GUIA CIRURGICO PARA IMPLANTE': ('Guia cirúrgico para implante', 98),
#  'ENXERTO OSSEO LIOFILIZADO': ('Enxerto com osso liofilizado', 91),
#  'ENXERTO OSSEO AUTOGENO': ('Enxerto com osso autógeno do mento', 73),
#  'LEVANTAMENTO DO SEIO MAXILAR COM OSSO AUTOGENO': ('Levantamento do seio maxilar com osso autógeno',
#   99),
#  'LEVANTAMENTO DO SEIO MAXILAR COM OSSO HOMOLOGO': ('Levantamento do seio maxilar com osso homólogo',
#   99),
#  'RESTAURAÇAO EM DENTE DECIDUO': ('RESTAURAÇÃO EM DENTE DECÍDUO', 96),
#  'DESSENSIBILIZACAO DENTARIA': ('Dessensibilização dentária', 94),
#  'RESTAURACAO TEMPORARIA / TRATAMENTO EXPECTANTE': ('Restauração temporária / tratamento expectante',
#   96),
#  'TESTE DE PH SALIVAR': ('Teste de Ph salivar', 100),
#  'CLAREAMENTO DE DENTE DESVITALIZADO': ('Clareamento de dente desvitalizado',
#   100),
#  'ADEQUACAO DE MEIO BUCAL COM IONOMERO DE VIDRO)': ('ADEQUAÇÃO DE MEIO BUCAL COM IONÔMERO DE VIDRO (BOCA COMPLETA)',
#   85),
#  'ESTABILIZACAO DE PACIENTE POR MEIO DE CONTENCAO FISICA E/OU MECANICA': ('Estabilização de paciente por meio de contenção física e/ou mecânica',
#   95),
#  'AMPUTACAO RADICULAR COM OBTURACAO RETROGRADA': ('Amputação radicular com obturação retrógrada',
#   94),
#  'AMPUTACAO RADICULAR SEM OBTURACAO RETROGRADA': ('AMPUTAÇAO RADICULAR SEM OBTURAÇAO RETROGRADA',
#   98),
#  'COROA TOTAL ACRILICA PRENSADA': ('Coroa total acrílica prensada', 98),
#  'REEMBASAMENTO DE COROA OU PROTESE TOTAL/PARCIAL': ('REEMBASAMENTO DE PRÓTESE TOTAL OU PARCIAL - MEDIATO (em consultório)',
#   83),
#  'RESTAURACAO EM CEROMERO - INLAY': ('RESTAURACAO EM CEROMERO ONLAY', 97),
#  'RESTAURACAO EM CEROMERO - ONLAY': ('RESTAURACAO EM CEROMERO ONLAY', 100),
#  'RESTAURACAO EM CERAMICA - INLAY': ('Restauração em cerâmica pura - inlay',
#   87),
#  'RESTAURACAO EM CERAMICA - ONLAY': ('Restauração em cerâmica pura - onlay',
#   87),
#  'COROA PROVISORIA': ('COROA PROVISÓRIA S/PINO', 79),
#  'OVERDENTURE BARRA CLIPE OU ORING SOBRE DOIS IMPLANTES': ("Overdenture barra clipe ou o'ring sobre dois implantes",
#   92),
#  'OVERDENTURE BARRA CLIPE OU ORING SOBRE TRES IMPLANTES': ("Overdenture barra clipe ou o'ring sobre três implantes",
#   91),
#  'OVERDENTURE BARRA CLIPE OU ORING SOBRE QUATRO OU MAIS IMPLANTES': ("Overdenture barra clipe ou o'ring sobre quatro ou mais implantes",
#   93),
#  'PRODUTOS: KIT ORTODONTICO': ('Kit ortodôntico - pasta', 77),
#  'ATIVIDADE EDUCATIVA EM SAUDE BUCAL': ('ATIVIDADE EDUCATIVA EM SAUDE BUCAL',
#   100),
#  'CONTROLE DE BIOFILME': ('CONTROLE DE BIOFILME (PLAC ', 89),
#  'TRATAMENTO DE MANUTENCAO PARA PERIODONTITE LEVE': ('Tratamento de pericoronarite',
#   64),
#  'CONTROLE DE CARIE INCIPIENTE': ('CONTROLE DE CÁRIE INCIPIENTE', 80),
#  'RESTAURACAO ATRAUMATICA EM DENTE PERMANENTE': ('RESTAURAÇÃO ATRAUMÁTICA EM DENTE PERMANENTE',
#   96),
#  'PREPARO PARA NUCLEO INTRARRADICULAR': ('PREPARO PARA NUCLEO INTRARRADICULAR',
#   100),
#  'CIRURGIA ODONTOLOGICA COM APLICACAO DE ALOENXERTOS': ('CIRURGIA ODONTOLÓGICA COM APLICAÇÃO DE ALOENXERTOS',
#   97),
#  'PUNCAO ASPIRATIVA NA REGIAO BUCO-MAXILO-FACIAL': ('PUNÇÃO ASPIRATIVA NA REGIAO BUCO-MAXILO-FACIAL',
#   98),
#  'RECONSTRUCAO DE DENTE COM PINO': ('RECONSTRUCAO DE PENIS COM ENXERTO', 83),
#  'CIRURGIA ODONTOLOGICA A RETALHO': ('Cirurgia odontológica a retalho', 98),
#  'IMPLANTE ORTODONTICO': ('Implante ortodôntico', 97),
#  'IMPLANTE ZIGOMATICO': ('Implante Zigomático', 97),
#  'LEVANTAMENTO DO SEIO MAXILAR COM OSSO LIOFILIZADO': ('Levantamento do seio maxilar com osso liofilizado',
#   100),
#  'ARCO LINGUAL': ('ARCO LINGUAL', 100),
#  'PISTAS DIRETAS DE PLANAS SUPERIOR E/OU INFERIOR': ('PISTAS DIRETAS DE PLANAS - SUPERIOR OU INFERIOR',
#   98),
#  'RESTAURACAO EM RESINA INDIRETA - INLAY': ('RESTAURAÇÃO EM RESINA (INDIRETA) - INLAY',
#   97),
#  'COROA TOTAL EM CERAMICA PURA': ('COROA TOTAL EM CERÂMICA PURA', 98),
#  'GUIA CIRURGICO PARA PROTESE TOTAL IMEDIATA': ('GUIA CIRURGICO PARA PRÓTESE TOTAL IMEDIATA',
#   99),
#  'RESTAURACAO EM RESINA INDIRETA - ONLAY': ('RESTAURAÇÃO EM RESINA (INDIRETA) - ONLAY',
#   97),
#  'REMOCAO DE TRABALHOS PROTETICOS': ('REMOÇÃO DE TRABALHO PROTÉTICO', 91),
#  'MARSUPIALIZACAO DE CISTOS ODONTOLOGICOS': ('MARSUPIALIZAÇÃO DE CISTOS ODONTOLÓGICOS',
#   96),
#  'CURETAGEM APICAL': ('CURETAGEM APICAL', 100),
#  'DIAGNOSTICO E PLANEJAMENTO PARA TRATAMENTO ODONTOLOGICO': ('DIAGNÓSTICO E PLANEJAMENTO PARA TRATAMENTO ODONTOLÓGICO',
#   98),
#  'DIAGNOSTICO POR MEIO DE descricaoS LABORATORIAIS': ('DIAGNÓSTICO POR MEIO DE PROCEDIMENTOS LABORATORIAIS',
#   73),
#  'APLICACAO DE LASER TERAPEUTICO': ('APLICAÇÃO DE LASER TERAPÊUTICO', 95),
#  'PROVISORIO PARA FACETA': ('PROVISÓRIO PARA FACETA', 98),
#  'PROVISORIO PARA INLAY/ONLAY': ('PROVISÓRIO PARA INLAY/ONLAY', 98),
#  'CONSULTA ODONTOLOGICA EM ESPECIALISTA': ('CONSULTA DE ESPECIALISTA EM ESTOMATOLOGIA',
#   85),
#  'TRATAMENTO DE MANUTENCAO PARA PERIODONTITE MODERADA': ('Pacote - Tratamento tipo I - manutenção mensal',
#   66),
#  'CONTROLE DE HEMORRAGIA COM APLICACAO DE AGENTE': ('Controle de hemorragia com aplicação de agente hemostático em região buco-maxilo-facial',
#   70),
#  'CONTROLE DE HEMORRAGIA SEM APLICACAO DE AGENTE': ('Controle de hemorragia sem aplicação de agente hemostático em região buco-maxilo-facial',
#   70),
#  'TRATAMENTO DE MANUTENCAO PARA PERIODONTITE GRAVE': ('Tratamento de abscesso periodontal agudo',
#   64),
#  'TRATAMENTO DE PERIOD. DE MANUT. P/ PERIODONTITE LEVE 6 EM 6 MESES': ('QUIMIOTERAPIA SISTEMICA POR PERIODOS DE 7 DIAS DE TRATAMENTO',
#   59),
#  'PLANEJAMENTO DE TRATAMENTO ORTODONTICO': ('DIAGNOSTICO E PLANEJAMENTO PARA TRATAMENTO ORTODONTICO',
#   83),
#  'TRATAMENTO DA ARTICULACAO TEMPOROMANDIBULAR ATM': ('Tratamento conservador de luxação da articulação têmporo-mandibular - ATM',
#   71),
#  'EXODONTIA SIMPLES DE PERMANENTE': ('Exodontia simples de permanente', 100),
#  'EMERGENCIA ODONTOLOGICA': ('CONSULTA ODONTOLOGICA', 68),
#  'TOMOGRAFIA': ('TONOGRAFIA', 90),
#  'PRODUTOS: CLOREXIDINA': ('Kit Clorexidina', 74),
#  'RADIOGRAFIA PANORAMICA': ('Radiografia Periapical', 82),
#  'MOLDAGEM ORTODONTICA': ('Modelos ortodônticos', 72),
#  'OSTEOPLASTIA': ('URETEROPLASTIA', 77),
#  'APARELHO DE PROTRACAO MANDIBULAR -  APM': ('Aparelho de protração mandibular -  APM',
#   97),
#  'ADESAO AO PLANO ORTODONTICO COMUM': ('ADESÃO AO PLANO ORTODÔNTICO', 86),
#  'APARELHO ORTODONTICO FIXO - RESINA': ('Aparelho ortodôntico fixo Resina',
#   98),
#  'APARELHO ORTODONTICO FIXO - PORCELANA': ('Aparelho ortodôntico fixo Porcelana',
#   99),
#  'APARELHO FIXO AUTO-LIGADO': ('Braquete Aparelho Auto Ligado', 78),
#  'APARELHO ORTODONTICO FIXO - SAFIRA': ('Aparelho ortodôntico fixo Safira',
#   98),
#  'APARELHO ORTODONTICO FIXO - METALICO': ('Aparelho ortodôntico fixo metálico',
#   97),
#  'APARELHO ORTODONTICO MOVEL': ('APARELHO ORTODÔNTICO FIXO', 84),
#  'APARELHO ORTODONTICO MOVEL ': ('APARELHO ORTODÔNTICO FIXO', 84),
#  'DENTE UNITARIO EM APARELHO ORTODÔNTICO': ('Dente unitário para aparelho ortodôntico',
#   88),
#  'ALETAS GOMES': ('Aletas Gomes', 100),
#  'APARELHO DE THUROW': ('Aparelho de Thurow', 100),
#  'APARELHO EXTRA-BUCAL': ('Aparelho extra-bucal', 100),
#  'APARELHO ORTODONTICO - MASCARA FACIAL': ('Aparelho Ortopédico (Mascara Facial)',
#   94),
#  'APARELHO ORTODONTICO - SPLINT': ('Porta Aparelho Ortodontico', 87),
#  'APARELHO PROTETOR BUCAL': ('Aparelho protetor bucal', 100),
#  'PROVISORIO PARA RESTAURACAO METALICA FUNDIDA': ('Provisório para Restauração metálica fundida',
#   95),
#  'INTERMEDIARIO PROTETICO (PARA IMPLANTES)': ('Intermediário protético (para implantes)',
#   97),
#  'MANUTENCAO DE PROTESE SOBRE IMPLANTES': ('PCT - Manutenção de prótese sobre implantes C/HM',
#   85),
#  'PROTOCOLO BRANEMARK PROVISORIO PARA 4 IMPLANTES': ('Protocolo Branemark provisório para 4 implantes',
#   99),
#  'REPOSICAO DE BRAQUETE METALICO': ('Braquete Metálico', 70),
#  'REPOSICAO DE BRAQUETE PORCELANA': ('Braquete Porcelana', 73),
#  'REPOSICAO DE BRAQUETE RESINA': ('Braquete Resina', 70),
#  'PRODUTOS: CERA ORTODONTICA': ('Cera Ortodontica', 78),
#  'PRODUTOS: CREME DENTAL': ('Creme Dental Paradontax', 77),
#  'PRODUTOS: ESCOVA DENTAL': ('PROVAS DE ESFORCO', 62),
#  'PRODUTOS: GEL BUCAL': ('Gel Bucal Sem Fluor', 59),
#  'MANUTENCAO ORTODONTICA - APARELHO AUTO-LIGADO': ('Manutenção de aparelho ortodôntico - Auto Ligado 180',
#   87),
#  'MANUTENCAO ORTODONTICA - APARELHO METALICO': ('Manutenção de aparelho ortodôntico - Metálico 80',
#   85),
#  'MANUTENCAO ORTODONTICA - APARELHO ORTOPEDICO': ('MANUTENÇAO DE APARELHO ORTODONTICO - APARELHO ORTOPEDICO',
#   84),
#  'COROA TOTAL METALO PLASTICA – RESINA ACRILICA': ('Coroa total metalo plástica - resina acrílica',
#   98),
#  'IMOBILIZACAO DENTARIA EM DENTES PERMANENTES': ('IMOBILIZACAO DENTARIA EM DENTES PERMANENTES',
#   100),
#  'PROTESE PROTOCOLO AJUSTE': ('PROTOCOLO DE FOTOS', 71),
#  'RESTAURACAO PROVISORIA': ('PCT - Restauração Provisória C/HM', 76),
#  'AVALIACAO ODONTOLOGICA ORTODONTICO': ('Avaliação Odontológica', 72),
#  'AVALIACAO ODONTOLOGICA CIRURGIA': ('Avaliação Odontológica', 76),
#  'AVALIACAO ODONTOLOGICA ENDODONTIA': ('Avaliação Odontológica', 73),
#  'AVALIACAO ODONTOLOGICA PROTESE': ('Avaliação Odontológica', 78),
#  'AVALIACAO ODONTOLOGICA IMPLANTE': ('Avaliação Odontológica', 76),
#  'AVALIACAO ODONTOLOGICA ESTETICA FACIAL': ('CONSULTA ODONTOLOGICA INICIAL',
#   69),
#  'AVALIACAO ODONTOLOGICA PERIODONTIA': ('Avaliação Odontológica', 72),
#  'AVALIACAO ODONTOLOGICA KIDS': ('Avaliação Odontológica', 83),
#  'PROTESE FIXA ADESIVA EM CEROMERO LIVRE DE METAL (METAL FREE)': ('Prótese fixa adesiva em cerômero livre de metal (metal free)',
#   98),
#  'MANUTENCAO ORTODONTICA - APARELHO RESINA': ('Manutenção de aparelho ortodôntico - Resina 80',
#   86),
#  'MANUTENCAO ORTODONTICA - APARELHO PORCELANA': ('Manutenção de aparelho ortodôntico - Porcelana 150',
#   86),
#  'MANUTENCAO ORTODONTICA KIDS': ('MANUTENÇÃO ORTODÔNTICA KIDS | R$ 85,00\t',
#   81),
#  'MANUTENCAO ORTODONTICA GRATUITA': ('MANUTENCAO PERIODONTAL KIT', 74),
#  'MANUTENCAO ORTODONTICA PROMOCIONAL (PRIMEIRA)': ('PRIMEIRA MANUTENÇÃO ORTODÔNTICA PROMOCIONAL',
#   96),
#  'AVALIACAO ODONTOLOGICA': ('Avaliação Odontológica', 93),
#  'DIAGNOSTICO E PLANEJAMENTO ORTODONTICO': ('DIAGNÓSTICO E PLANEJAMENTO ODONTOLÓGICO',
#   91),
#  'BIOPSIA DE BOCABIOPSIA DE LABIOBIOPSIA DE LINGUABIOPSIA DE MANDIBULABIOPSIA DE MAXILABIOPSIA DE GLANDULA SALIVAR': ('LARINGOSCOPIA DIRETA - PARA DIAGNOSTICO, COLHEITA DE MATERIAL E/OU BIOPSIA',
#   48)}

# %%
# Sample data from our company and competitors
# our_products = ["iPhone X", "iPad Pro", "MacBook Air", "Apple Watch", "AirPods"]
# competitor_products = ["iFone X", "iTablet Pro", "Mac Air", "iWatch", "Earbuds"]

# Mapping our products with competitor products using fuzzy matching
# mapped_products = {}
# for our_product in our_products:
#     best_match_index, similarity_score = find_most_similar_product(
#         our_product, competitor_products
#     )

#     mapped_products[our_product] = (
#         competitor_products[best_match_index],
#         similarity_score,
#     )

# # Displaying the mapped products
# print("Product Mapping:")
# for our_product, (competitor_product, similarity_score) in mapped_products.items():
#     print(f"{our_product} => {competitor_product} (Similarity: {similarity_score})")

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------------------

# %%
def compare_strings(a, b):
    return fuzz.token_sort_ratio(a, b)


def fuzzy_procedimento_generico(df, threshold=90):
    duplicates = set()
    processed = []

    for i, row in df.iterrows():
        if i not in duplicates:
            processed.append(row)

            for j, other_row in df.iterrows():
                if i != j and j not in duplicates:
                    score = compare_strings(
                        row["descricao"], other_row["procedimento_generico"]
                    )

                    if score >= threshold:
                        duplicates.add(j)

    return pd.DataFrame(processed)


fuzzy_procedimento_generico(df, threshold=80)

# %%
def return_results(list_of_dicts, query, threshold):
    scores = []
    for index, item in enumerate(list_of_dicts):
        values = list(item.values())
        ratios = [
            fuzz.ratio(str(query), str(value)) for value in values
        ]  # ensure both are in string
        scores.append({"index": index, "score": max(ratios)})

    filtered_scores = [item for item in scores if item["score"] >= threshold]
    sorted_filtered_scores = sorted(
        filtered_scores, key=lambda k: k["score"], reverse=True
    )
    filtered_list_of_dicts = [
        list_of_dicts[item["index"]] for item in sorted_filtered_scores
    ]
    return filtered_list_of_dicts

# %%
# df.drop_duplicates(')
