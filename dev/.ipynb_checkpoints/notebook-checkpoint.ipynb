# %%
import pandas as pd

# %%
df = pd.read_parquet('df_data_virada.parquet')

# %%
df
# Out:
#         id_unidade  atendimento_id_unidade_ati   unidade  ati_id  \
# 0           566812                      273822  boavista   56681
# 1           579232                      279252  boavista   57923
# 2          1449861                      675091    olinda  144986
# 5           660752                      312662  boavista   66075
# 6           660762                      312662  boavista   66076
# ...            ...                         ...       ...     ...
# 916704     2593052                     1042432  boavista  259305
# 916706     2593032                     1042432  boavista  259303
# 916707     2593082                     1042442  boavista  259308
# 916709     2593072                     1042442  boavista  259307
# 916710     2593102                     1042452  boavista  259310
#
#         procedimento_id data_cobranca data_realizacao  \
# 0                592580    2020-03-03      2020-12-01
# 1                592580    2020-03-13      2020-12-09
# ...
